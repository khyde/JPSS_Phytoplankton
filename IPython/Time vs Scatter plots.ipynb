# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
plt.style.use('seaborn')

# %%
data82018 = pd.read_csv ('2018-08.csv')
data112018 = pd.read_csv ('2018-11.csv')
data52019 = pd.read_csv ('2019-05.csv')
data102019 = pd.read_csv ('2019-10.csv')

# %%
date82018 = data82018.date
temp82018 = data82018.temperature
sal82018 = data82018.salinity
chl82018 = data82018.chl_ctd
cdom82018 = data82018.cdom_ctd

date112018 = data112018.date
temp112018 = data112018.temperature
sal112018 = data112018.salinity
chl112018 = data112018.chl_ctd
cdom112018 = data112018.cdom_ctd

date52019 = data52019.date
temp52019 = data52019.temperature
sal52019 = data52019.salinity
chl52019 = data52019.chl_ctd
cdom52019 = data52019.cdom_ctd

date102019 = data102019.date
temp102019 = data102019.temperature
sal102019 = data102019.salinity
chl102019 = data102019.chl_ctd
cdom102019 = data102019.cdom_ctd

# %%
date82018 = pd.to_datetime(date82018)
date112018 = pd.to_datetime(date112018)
date52019 = pd.to_datetime(date52019)
date102019 = pd.to_datetime(date102019)

# %%
# This is essentially a base set of lines to make sure every tool necessary is available and the data sets are in a managable form

# %%
data52019
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3200   -71.4210  2019-05-22 19:44:59.0      5      13.4309
# 1      41.2825   -71.4210  2019-05-22 19:55:32.0      5      13.1200
# 2      41.2518   -71.4201  2019-05-22 20:05:33.0      5      13.2860
# 3      41.2210   -71.4198  2019-05-22 20:15:33.0      5      13.4242
# 4      41.1905   -71.4210  2019-05-22 20:25:34.0      5      13.1448
# ...        ...        ...                    ...    ...          ...
# 1081   42.8329   -67.8352  2019-06-02 15:50:31.0      5       9.3813
# 1082   42.8492   -67.8325  2019-06-02 16:00:31.0      5       9.2167
# 1083   42.8787   -67.8265  2019-06-02 16:10:31.0      5       8.9657
# 1084   42.9086   -67.8209  2019-06-02 16:20:31.0      5       9.1003
# 1085   43.4120   -67.7110  2019-06-02 20:15:00.0      5       9.0000
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3542   0.3751  0.0640    2.1672    2.1816          NaN
# ...

# %%
plt.scatter (data82018.date, data82018.salinity)

# %%
plt.scatter (data82018.date, data82018.temperature, color = ['r'])

# %%
plt.scatter (data82018.date, data82018.chl_ctd, color = ['g'])
plt.scatter (data82018.date, data82018.cdom_ctd, color = ['c'])

# %%
plt.scatter (data82018.date, data82018.chl_ctd, color = ['g'])

# %%
plt.scatter (data82018.date, data82018.cdom_ctd, color = ['c'])

# %%
plt.scatter (data112018.date, data112018.cdom_ctd, color = ['c'])
plt.scatter (data112018.date, data112018.chl_ctd, color = ['g'])
plt.scatter (data112018.date, data112018.temperature, color = ['r'])
plt.scatter (data112018.date, data112018.salinity)
plt.xlabel ("Time")
plt.title ('November 2018 Collected Data')
plt.show ()

# %%
plt.scatter (data112018.date, data112018.cdom_ctd, color = ['c'])
plt.scatter (data112018.date, data112018.chl_ctd, color = ['g'])
plt.scatter (data112018.date, data112018.temperature, color = ['r'])
plt.scatter (data112018.date, data112018.salinity)

# %%
plt.scatter (data52019.date, data52019.cdom_ctd, color = ['c'])
plt.scatter (data52019.date, data52019.chl_ctd, color = ['g'])
plt.scatter (data52019.date, data52019.temperature, color = ['r'])
plt.scatter (data52019.date, data52019.salinity)
plt.xlabel ("Time")
plt.title ('May 2019 Collected Data')
plt.show ()

# %%
plt.scatter (data102019.date, data102019.cdom_ctd, color = ['c'])
plt.scatter (data102019.date, data102019.chl_ctd, color = ['g'])
plt.scatter (data102019.date, data102019.temperature, color = ['r'])
plt.scatter (data102019.date, data102019.salinity)
plt.xlabel ("Time")
plt.title ('October 2019 Collected Data')
plt.show ()

# %%
# Had some difficulty getting labels to show up properly so I will take time to format It correctly

# %%
# Will format time soon, ultimately ran out of time while trying to find a proper formatting system that would also appear on the chart

# %%
plt.scatter (data82018.date, data82018.cdom_ctd, color = ['c'])
plt.scatter (data82018.date, data82018.chl_ctd, color = ['g'])
plt.scatter (data82018.date, data82018.temperature, color = ['r'])
plt.scatter (data82018.date, data82018.salinity)
plt.xlabel ("Time")
plt.title ('August 2018 Collected Data')
plt.show ()

# %%
plt.scatter (data82018.temperature, data82018.salinity)

# %%
feature_cols = ['temperature', 'chl_ctd', 'cdom_ctd']

# %%
x = data82018[feature_cols]

# %%
x = data82018[['temperature', 'chl_ctd', 'cdom_ctd']]

# %%
x
# Out:
#       temperature  chl_ctd  cdom_ctd
# 0         22.9616   3.0008    2.2575
# 1         22.9605   1.4036    3.7926
# 2         22.8414   1.0527    9.7975
# 3         22.6832   0.6050    2.5284
# 4         22.2266   0.6655   12.1454
# ...           ...      ...       ...
# 1153      27.3766   0.1210    1.1739
# 1154      27.3393   0.1089    1.4448
# 1155      27.5079   0.1452    1.5351
# 1156      27.5168   0.1452    1.4448
# 1157      27.6020   0.1331    1.4448
#
# [1158 rows x 3 columns]

# %%
y = data82018['salinity']

# %%
from sklearn.model_selection import train_test_split

# %%
# ignore the line above

# %%
plt.style.use('seaborn')

# %%
plt.scatter (x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-a05569d4a582> in <module>
# ----> 1 plt.scatter (x, y)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2846         verts=verts, edgecolors=edgecolors,
#    2847         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2848         None else {}), **kwargs)
#    2849     sci(__ret)
#    2850     return __ret
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
plt.scatter (data82018.temperature, data82018.salinity)

# %%
plt.scatter (data82018.temperature, data82018.salinity, edgecolor = 'black')

# %%
plt.scatter (data82018.temperature, data82018.salinity, edgecolor = 'black', alpha = 0.75)

# %%
plt.scatter (data82018.temperature, data82018.salinity, edgecolor = 'black', alpha = 0.75, cmap ='Greens')

# %%
plt.scatter ((data82018.temperature, data82018.salinity), (data82018.temperature, data82018.chl_ctd), edgecolor = 'black', alpha = 0.75)

# %%
plt.scatter ((data82018.temperature, data82018.salinity), (data82018.chl_ctd, data82018.temperature), edgecolor = 'black', alpha = 0.75)

# %%
colors = ['']

# %%
#It is important to include this(^) line if you want colors to work

# %%
plt.scatter (data82018.temperature, data82018.salinity, s=100, cmap='blues', edgecolor = 'black', alpha = 0.75)
plt.title ('Temperature vs Salinity')
plt.xlabel ("Salinity (CPU)")
plt.ylabel ("Temperature (C)")
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %%
cbar = plt.colorbar ()
cbar.set_label('Label')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-38-eef086c9206b> in <module>
# ----> 1 cbar = plt.colorbar ()
#       2 cbar.set_label('Label')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2079         mappable = gci()
#    2080         if mappable is None:
# -> 2081             raise RuntimeError('No mappable was found to use for colorbar '
#    2082                                'creation. First define a mappable such as '
#    2083                                'an image (with imshow) or a contour set ('
#
# RuntimeError: No mappable was found to use for colorbar creation. First define a mappable such as an image (with imshow) or a contour set (with contourf).

# %%
plt.scatter (data82018.temperature, data82018.salinity, s=100, cmap='blues', edgecolor = 'black', alpha = 0.75)
plt.xscale ('log')
plt.yscale ('log')
plt.title ('Temperature vs Salinity')
plt.xlabel ("Salinity (CPU)")
plt.ylabel ("Temperature (C)")
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %%
#this is where I got the whole color thing right

# %%
sal82018 = data82018['temperature']

# %%
temp82018 = data82018['temperature']

# %%
plt.scatter (data82018.temperature, data82018.salinity, s=100, c=temp82018,cmap='Reds', edgecolor = 'black', alpha = 0.75)
plt.xscale ('log')
plt.yscale ('log')
plt.title ('Temperature vs Salinity')
plt.xlabel ("Salinity (CPU)")
plt.ylabel ("Temperature (C)")
cbar = plt.colorbar ()
cbar.set_label('Salinity')

# %%
plt.scatter (data82018.temperature, data82018.salinity, s=100, c=temp82018,cmap='Reds', edgecolor = 'black', alpha = 0.75)
plt.figure (figsize=(20,10))
plt.xscale ('log')
plt.yscale ('log')
plt.title ('Temperature vs Salinity')
plt.xlabel ("Salinity (CPU)")
plt.ylabel ("Temperature (C)")
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %%
sns.regplot (x='data82018.salinity', y='data82018.temperature', data = 'data82018')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-25c8cb81e653> in <module>
# ----> 1 sns.regplot (x='data82018.salinity', y='data82018.temperature', data = 'data82018')
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     808                                  order, logistic, lowess, robust, logx,
#     809                                  x_partial, y_partial, truncate, dropna,
# --> 810                                  x_jitter, y_jitter, color, label)
#     811
#     812     if ax is None:
#
# ...

# %%
data82018
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3639   -71.4220  2018-08-22 20:05:33.0      4      22.9616
# 1      41.3397   -71.4215  2018-08-22 20:15:34.0      4      22.9605
# 2      41.3143   -71.4218  2018-08-22 20:25:34.0      4      22.8414
# 3      41.2886   -71.4227  2018-08-22 20:35:34.0      4      22.6832
# 4      41.2631   -71.4226  2018-08-22 20:45:34.0      4      22.2266
# ...        ...        ...                    ...    ...          ...
# 1153   36.6353   -75.0009  2018-08-30 23:09:42.0      4      27.3766
# 1154   36.6121   -75.0006  2018-08-30 23:19:42.0      4      27.3393
# 1155   36.5841   -75.0000  2018-08-30 23:29:42.0      4      27.5079
# 1156   36.5565   -75.0001  2018-08-30 23:39:42.0      4      27.5168
# 1157   36.5290   -75.0004  2018-08-30 23:49:42.0      4      27.6020
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3731   3.0008  0.1708    2.2575    6.0672          NaN
# ...

# %%
data82018.plot.scatter (data82018.salinity, data82018.temperature)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-a650b27152d4> in <module>
# ----> 1 data82018.plot.scatter (data82018.salinity, data82018.temperature)
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwargs)
#    1497             ...                       colormap='viridis')
#    1498         """
# -> 1499         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1500
#    1501     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     790         if kind in self._dataframe_kinds:
#     791             if isinstance(data, ABCDataFrame):
# --> 792                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     793             else:
# ...

# %%
banana_weight=[3,3,3,10,10,1,1,1,4,4,4,4,7,7,7]
mango_weight=[3,3,3,10,10,1,1,1,4,4,4,4,7,7,7]

fig=plt.figure()
ax1=fig.add_subplot(312)
ax2=fig.add_subplot(313)
ax1.hist(banana_weight)
ax2.hist(mango_weight)
plt.show()

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing both axes')
ax2.scatter(x, y)
ax3.scatter(x, 2 * y ** 2 - 1, color='r')
# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-1cc37e389882> in <module>
#       1 f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True)
# ----> 2 ax1.plot(x, y)
#       3 ax1.set_title('Sharing both axes')
#       4 ax2.scatter(x, y)
#       5 ax3.scatter(x, 2 * y ** 2 - 1, color='r')
#
# NameError: name 'x' is not defined

# %%
sns.set(color_codes=True)

# %%
tips = sns.load_dataset("tips")

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data82018
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3639   -71.4220  2018-08-22 20:05:33.0      4      22.9616
# 1      41.3397   -71.4215  2018-08-22 20:15:34.0      4      22.9605
# 2      41.3143   -71.4218  2018-08-22 20:25:34.0      4      22.8414
# 3      41.2886   -71.4227  2018-08-22 20:35:34.0      4      22.6832
# 4      41.2631   -71.4226  2018-08-22 20:45:34.0      4      22.2266
# ...        ...        ...                    ...    ...          ...
# 1153   36.6353   -75.0009  2018-08-30 23:09:42.0      4      27.3766
# 1154   36.6121   -75.0006  2018-08-30 23:19:42.0      4      27.3393
# 1155   36.5841   -75.0000  2018-08-30 23:29:42.0      4      27.5079
# 1156   36.5565   -75.0001  2018-08-30 23:39:42.0      4      27.5168
# 1157   36.5290   -75.0004  2018-08-30 23:49:42.0      4      27.6020
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3731   3.0008  0.1708    2.2575    6.0672          NaN
# ...

# %%
sns.regplot(x="temperature", y="salinity", data=data82018)

# %%
sns.regplot(x="temperature", y="salinity", data=data82018)
plt.xscale ('log')
plt.yscale ('log')
plt.title ('Temperature vs Salinity')
plt.xlabel ("Salinity (CPU)")
plt.ylabel ("Temperature (C)")
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %%
#pretty pretty good success

# %%
sns.regplot(x="temperature", y="salinity", figsize=(15,15), data=data82018)
plt.xscale ('log')
plt.yscale ('log')
plt.title ('Temperature vs Salinity')
plt.xlabel ("Salinity (CPU)")
plt.ylabel ("Temperature (C)")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-74d90fe0c502> in <module>
# ----> 1 sns.regplot(x="temperature", y="salinity", figsize=(15,15), data=data82018)
#       2 plt.xscale ('log')
#       3 plt.yscale ('log')
#       4 plt.title ('Temperature vs Salinity')
#       5 plt.xlabel ("Salinity (CPU)")
#
# TypeError: regplot() got an unexpected keyword argument 'figsize'

# %%
#stack overflow for changing sizes sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
sns.regplot(x="temperature", y="salinity", color='b', data=data82018)
plt.xscale ('log')
plt.yscale ('log')
plt.title ('Temperature vs Salinity')
plt.xlabel ("Salinity (CPU)")
plt.ylabel ("Temperature (C)")
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %%
sns.regplot(x="temperature", y="chl_ctd", color='g', data=data82018)
plt.xscale ('log')
plt.yscale ('log')
plt.title ('Temperature vs Chlorophyll')
plt.xlabel ("Chlorophyll (uG/L)")
plt.ylabel ("Temperature (C)")
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %%
sns.regplot(x="temperature", y="cdom_ctd", color='c', data=data82018)
plt.xscale ('log')
plt.yscale ('log')
plt.title ('Temperature vs Dissolved Organic Matter')
plt.xlabel ("Dissolved Organic Matter")
plt.ylabel ("Temperature (C)")
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %%
sns.regplot(x="temperature", y="cdom_ctd", color='c', data=data82018)
plt.xscale ('log')
plt.yscale ('log')
plt.title ('Temperature vs Dissolved Organic Matter')
plt.xlabel ("Dissolved Organic Matter")
plt.ylabel ("Temperature (C)")
sns.set(rc={'figure.figsize':(14,10)})

# %%
#its alve!!!

# %%
sns.regplot(x="temperature", y="cdom_ctd", color='c', data=data82018)
plt.title ('Temperature vs Dissolved Organic Matter')
plt.ylabel ("Dissolved Organic Matter")
plt.xlabel ("Temperature (C)")
sns.set(rc={'figure.figsize':(14,10)})

# %%
#make sure to check your labels

# %%
#don't log temperature

# %%
data82018
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3639   -71.4220  2018-08-22 20:05:33.0      4      22.9616
# 1      41.3397   -71.4215  2018-08-22 20:15:34.0      4      22.9605
# 2      41.3143   -71.4218  2018-08-22 20:25:34.0      4      22.8414
# 3      41.2886   -71.4227  2018-08-22 20:35:34.0      4      22.6832
# 4      41.2631   -71.4226  2018-08-22 20:45:34.0      4      22.2266
# ...        ...        ...                    ...    ...          ...
# 1153   36.6353   -75.0009  2018-08-30 23:09:42.0      4      27.3766
# 1154   36.6121   -75.0006  2018-08-30 23:19:42.0      4      27.3393
# 1155   36.5841   -75.0000  2018-08-30 23:29:42.0      4      27.5079
# 1156   36.5565   -75.0001  2018-08-30 23:39:42.0      4      27.5168
# 1157   36.5290   -75.0004  2018-08-30 23:49:42.0      4      27.6020
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3731   3.0008  0.1708    2.2575    6.0672          NaN
# ...

# %%
sns.regplot(x="temperature", y="salinity", color='r', data=data82018)
plt.title ('Temperature vs Salinity')
plt.ylabel ("Salinity (PGU)")
plt.xlabel ("Temperature (C)")
sns.set(rc={'figure.figsize':(14,10)})

# %%
plt.scatter (date52019, chl52019)

# %%
plt.scatter (date52019, temp52019)
