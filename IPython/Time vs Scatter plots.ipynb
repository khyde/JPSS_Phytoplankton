# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
data82018 = pd.read_csv ('2018-08.csv')
data112018 = pd.read_csv ('2018-11.csv')
data52019 = pd.read_csv ('2019-05.csv')
data102019 = pd.read_csv ('2019-10.csv')

# %%
# This is essentially a base set of lines to make sure every tool necessary is available and the data sets are in a managable form

# %%
data52019
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3200   -71.4210  2019-05-22 19:44:59.0      5      13.4309
# 1      41.2825   -71.4210  2019-05-22 19:55:32.0      5      13.1200
# 2      41.2518   -71.4201  2019-05-22 20:05:33.0      5      13.2860
# 3      41.2210   -71.4198  2019-05-22 20:15:33.0      5      13.4242
# 4      41.1905   -71.4210  2019-05-22 20:25:34.0      5      13.1448
# ...        ...        ...                    ...    ...          ...
# 1081   42.8329   -67.8352  2019-06-02 15:50:31.0      5       9.3813
# 1082   42.8492   -67.8325  2019-06-02 16:00:31.0      5       9.2167
# 1083   42.8787   -67.8265  2019-06-02 16:10:31.0      5       8.9657
# 1084   42.9086   -67.8209  2019-06-02 16:20:31.0      5       9.1003
# 1085   43.4120   -67.7110  2019-06-02 20:15:00.0      5       9.0000
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3542   0.3751  0.0640    2.1672    2.1816          NaN
# ...

# %%
plt.scatter (data82018.date, data82018.salinity)

# %%
plt.scatter (data82018.date, data82018.temperature, color = ['r'])

# %%
plt.scatter (data82018.date, data82018.chl_ctd, color = ['g'])
plt.scatter (data82018.date, data82018.cdom_ctd, color = ['c'])

# %%
plt.scatter (data82018.date, data82018.chl_ctd, color = ['g'])

# %%
plt.scatter (data82018.date, data82018.cdom_ctd, color = ['c'])

# %%
plt.scatter (data112018.date, data112018.cdom_ctd, color = ['c'])
plt.scatter (data112018.date, data112018.chl_ctd, color = ['g'])
plt.scatter (data112018.date, data112018.temperature, color = ['r'])
plt.scatter (data112018.date, data112018.salinity)
plt.xlabel ("Time")
plt.title ('November 2018 Collected Data')
plt.show ()

# %%
plt.scatter (data112018.date, data112018.cdom_ctd, color = ['c'])
plt.scatter (data112018.date, data112018.chl_ctd, color = ['g'])
plt.scatter (data112018.date, data112018.temperature, color = ['r'])
plt.scatter (data112018.date, data112018.salinity)

# %%
plt.scatter (data52019.date, data52019.cdom_ctd, color = ['c'])
plt.scatter (data52019.date, data52019.chl_ctd, color = ['g'])
plt.scatter (data52019.date, data52019.temperature, color = ['r'])
plt.scatter (data52019.date, data52019.salinity)
plt.xlabel ("Time")
plt.title ('May 2019 Collected Data')
plt.show ()

# %%
plt.scatter (data102019.date, data102019.cdom_ctd, color = ['c'])
plt.scatter (data102019.date, data102019.chl_ctd, color = ['g'])
plt.scatter (data102019.date, data102019.temperature, color = ['r'])
plt.scatter (data102019.date, data102019.salinity)
plt.xlabel ("Time")
plt.title ('October 2019 Collected Data')
plt.show ()

# %%
# Had some difficulty getting labels to show up properly so I will take time to format It correctly

# %%
# Will format time soon, ultimately ran out of time while trying to find a proper formatting system that would also appear on the chart

# %%
plt.scatter (data82018.date, data82018.cdom_ctd, color = ['c'])
plt.scatter (data82018.date, data82018.chl_ctd, color = ['g'])
plt.scatter (data82018.date, data82018.temperature, color = ['r'])
plt.scatter (data82018.date, data82018.salinity)
plt.xlabel ("Time")
plt.title ('August 2018 Collected Data')
plt.show ()
