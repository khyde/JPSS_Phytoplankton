# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
import numpy as np
import seaborn as sns

# %%
data82018 = pd.read_csv ('2018-08.csv')
data112018 = pd.read_csv ('2018-11.csv')
data52019 = pd.read_csv ('2019-05.csv')
data102019 = pd.read_csv ('2019-10.csv')

# %%
date82018 = data82018.date
temp82018 = data82018.temperature
sal82018 = data82018.salinity
chl82018 = data82018.chl_ctd
cdom82018 = data82018.cdom_ctd

date112018 = data112018.date
temp112018 = data112018.temperature
sal112018 = data112018.salinity
chl112018 = data112018.chl_ctd
cdom112018 = data112018.cdom_ctd

date52019 = data52019.date
temp52019 = data52019.temperature
sal52019 = data52019.salinity
chl52019 = data52019.chl_ctd
cdom52019 = data52019.cdom_ctd

date102019 = data102019.date
temp102019 = data102019.temperature
sal102019 = data102019.salinity
chl102019 = data102019.chl_ctd
cdom102019 = data102019.cdom_ctd

# %%
temp112018 = data112018.temperature
sal112018 = data112018.salinity
chl112018 = data112018.chl_ctd
codm112018 = data112018.cdom_ctd

# %%
temp52019 = data52019.temperature
sal52019 = data52019.salinity
chl52019 = data52019.chl_ctd
codm52019 = data52019.cdom_ctd

# %%
temp102019 = data102019.temperature
sal102019 = data102019.salinity
chl102019 = data102019.chl_ctd
codm102019 = data102019.cdom_ctd

# %%
banana_weight=[3,3,3,10,10,1,1,1,4,4,4,4,7,7,7]
mango_weight=[3,3,3,10,10,1,1,1,4,4,4,4,7,7,7]

fig=plt.figure()
ax1=fig.add_subplot(312)
ax2=fig.add_subplot(313)
ax1.hist(banana_weight)
ax2.hist(mango_weight)
plt.show()

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing both axes')
ax2.scatter(x, y)
ax3.scatter(x, 2 * y ** 2 - 1, color='r')
# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1cc37e389882> in <module>
#       1 f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True)
# ----> 2 ax1.plot(x, y)
#       3 ax1.set_title('Sharing both axes')
#       4 ax2.scatter(x, y)
#       5 ax3.scatter(x, 2 * y ** 2 - 1, color='r')
#
# NameError: name 'x' is not defined

# %%
#pure stack overflow

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True)
ax1.plot(sal82018, temp82018)
ax1.set_title('Everything vs cdom')
ax2.scatter(chl82018, temp82018)
ax3.scatter(cdom82018, 2 * temp82018 ** 2 - 1, color='r')
# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
#test 1

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=False)
ax1.set_title('Everything vs cdom')
ax1.plot(sal82018, temp82018)
ax2.scatter(chl82018, temp82018)
ax3.scatter(cdom82018, 2 * temp82018 ** 2 - 1, color='r')
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
#test 2

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=False)
ax1.set_title('Everything vs cdom')
ax1.plot(sal82018, temp82018)
ax2.plot(chl82018, temp82018, color='g')
ax3.plot(cdom82018, 2 * temp82018 ** 2 - 1, color='c')
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
#test 3

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=False)
ax1.set_title('Everything vs cdom')
ax1.plot(sal82018, temp82018)
ax2.plot(chl82018, temp82018, color='g')
ax3.plot(cdom82018, temp82018, color='c')
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
#test 4

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=False)
ax1.set_title('2018 Time Series')
ax1.plot(data82018.date, sal82018)
ax2.plot(data82018.date, chl82018, color='g')
ax3.plot(data82018.date, cdom82018, color='c')
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
#test 5

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=False)
ax1.set_title('2018 Time Series')
ax1.plot(data82018.date, sal82018)
ax2.plot(data82018.date, chl82018, color='g')
ax3.plot(data82018.date, cdom82018, color='c')
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
plt.figure (figsize=(20,10))

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=False)
ax1.set_title('2018 Time Series')
ax1.plot(data82018.date, sal82018)
ax2.plot(data82018.date, chl82018, color='g')
ax3.plot(data82018.date, cdom82018, color='c')
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
plt.figure (figsize=(10,5))

# %%
#plt.savefig('myfig.png') to save the final for the presentation

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=False)
ax1.set_title('2018 Time Series')
ax1.plot(data82018.date, sal82018)
ax2.plot(data82018.date, chl82018, color='g')
ax3.plot(data82018.date, cdom82018, color='c')
plt.legend (["Salanity (PGU)", "Chlorophyll (uG/L)", "Dissolved Organic Material"])
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False)
ax1.plot(date82018, temp82018, color='r')
ax1.legend (["Temperature (°C)"], shadow=True)
ax1.set_title('2018 Time Series')
ax2.plot(date82018, sal82018)
ax2.legend (["Salinity (PGU)"], shadow=True)
ax3.plot(date82018, chl82018, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True)
ax4.plot(date82018, cdom82018, color='c')
ax4.legend (["CDOM"], shadow=True)
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
#ideal-ish chart

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False)
ax1.plot(date52019, temp52019, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('May 2019 Time Series')
ax2.plot(date52019, sal52019)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date52019, chl52019, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date52019, cdom52019, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
#axes[0].axhline(0.5,color='black',ls='--') = overflow how to get a line in a subplot

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False)
ax1.plot(date52019, temp52019, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('May 2019 Time Series')
ax2.plot(date52019, sal52019)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date52019, chl52019, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date52019, cdom52019, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
axes = [ax1, ax2, ax3, ax4]

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False)
ax1.plot(date52019, temp52019, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('May 2019 Time Series')
ax2.plot(date52019, sal52019)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date52019, chl52019, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date52019, cdom52019, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
f.subplots_adjust(hspace=0)
plt.figure (figsize=(20,10))
plt.savefig('52019lines1.png')
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
plt.savefig('52019line.png')

# %%
plt.show ()

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False)
ax1.plot(date82018, temp82018, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('August 2018 Time Series')
ax2.plot(date82018, sal82018)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date82018, chl82018, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date82018, cdom82018, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
f.subplots_adjust(hspace=0)
plt.savefig('82018lines1.png')
plt.figure (figsize=(20,10))
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False)
ax1.plot(date112018, temp112018, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('November 2018 Time Series')
ax2.plot(date112018, sal112018)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date112018, chl112018, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date112018, cdom112018, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
f.subplots_adjust(hspace=0)
plt.savefig('112018lines1.png')
plt.figure (figsize=(20,10))
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False)
ax1.plot(date102019, temp102019, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('October 2019 Time Series')
ax2.plot(date102019, sal102019)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date102019, chl102019, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date102019, cdom102019, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
f.subplots_adjust(hspace=0)
plt.figure (figsize=(20,10))
plt.savefig('102019lines1.png')
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False)
ax1.plot(date102019, temp102019, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('October 2019 Time Series')
ax2.plot(date102019, sal102019)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date102019, chl102019, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date102019, cdom102019, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
f.subplots_adjust(hspace=0)
plt.savefig('102019lines1.png')
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
#to get a pic you gotta get rid of the size thing

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False)
ax1.plot(date52019, temp52019, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('May 2019 Time Series')
ax2.plot(date52019, sal52019)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date52019, chl52019, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date52019, cdom52019, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
f.subplots_adjust(hspace=0)
plt.savefig('52019lines1.png')
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
plt.plot (date82018, temp82018)

# %%
plt.plot (date82018, temp82018, figsize=(10,3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-76467ee6f243> in <module>
# ----> 1 plt.plot (date82018, temp82018, figsize=(10,3))
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ...

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False, figsize=(15,15))
ax1.plot(date52019, temp52019, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('May 2019 Time Series')
ax2.plot(date52019, sal52019)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date52019, chl52019, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date52019, cdom52019, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
f.subplots_adjust(hspace=0)
plt.savefig('52019lines1.png')
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
#Successes!!

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False, figsize=(15,15))
ax1.plot(date112018, temp112018, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('November 2018 Time Series')
ax2.plot(date112018, sal112018)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date112018, chl112018, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date112018, cdom112018, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
f.subplots_adjust(hspace=0)
plt.savefig('112018ines2.png')
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
plt.plot (date82018, temp82018)

# %%
plt.plot (date82018(8/22/2018, 8/30/2018), temp82018)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-8c77825cd496> in <module>
# ----> 1 plt.plot (date82018(8/22/2018, 8/30/2018), temp82018)
#
# TypeError: 'Series' object is not callable

# %%
x= np.arange(8/22/2018, 8/30/2018)

# %%
plt.plot (date82018, temp82018)

# %%
plt.gcf ()

# %%
#this allows you to edit the most recent graph

# %%
plt.gcf ().autofmt_xdate()

# %%
plt.plot (date82018, temp82018)
plt.gcf ().autofmt_xdate()

# %%
plt.plot (date82018, temp82018, figsize=(8, 6))
plt.gcf ().autofmt_xdate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-e58211a4b602> in <module>
# ----> 1 plt.plot (date82018, temp82018, figsize=(8, 6))
#       2 plt.gcf ().autofmt_xdate()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ...

# %%
# fig = matplotlib.pyplot.gcf()
#fig.set_size_inches(18.5, 10.5)

# %%
#from stack

# %%
plt.plot (date82018, temp82018)
plt.gcf ().autofmt_xdate()

# %%
fig = plt.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-267645809101> in <module>
# ----> 1 fig = plt.pyplot.gcf()
#       2 fig.set_size_inches(18.5, 10.5)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'pyplot'

# %%
import matplotlib.pyplot

# %%
#didnt work

# %%
plt.style.use('seaborn')

# %%
plt.plot (date82018, temp82018)
plt.gcf ().autofmt_xdate()

# %%
plt.plot (date82018, temp82018)
plt.gcf ().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b, %d %y')
plt.gca ().xaxis.set_major_formatter(date_format)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
# ...

# %%
#just to make sure that they are downloaded for tomorrow

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False, figsize=(15,15))
ax1.plot(date82018, temp82018, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('August 2018 Time Series')
ax2.plot(date82018, sal82018)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date82018, chl82018, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date82018, cdom82018, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
plt.gcf ().autofmt_xdate()
f.subplots_adjust(hspace=0)
plt.savefig('82018ines2.png')
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False, figsize=(25,25))
ax1.plot(date112018, temp112018, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('November 2018 Time Series')
ax2.plot(date112018, sal112018)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date112018, chl112018, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date112018, cdom112018, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
plt.gcf ().autofmt_xdate()
f.subplots_adjust(hspace=0)
plt.savefig('112018ines3.png')
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False, figsize=(25,25))
ax1.plot(date52019, temp52019, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('May 2019 Time Series')
ax2.plot(date52019, sal52019)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date52019, chl52019, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date52019, cdom52019, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
plt.gcf ().autofmt_xdate()
f.subplots_adjust(hspace=0)
plt.savefig('52019ines3.png')
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False, figsize=(25,25))
ax1.plot(date102019, temp102019, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('October 2019 Time Series')
ax2.plot(date102019, sal102019)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date102019, chl102019, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date102019, cdom102019, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
a1.set_xlim(0,10) aource axis restrictor
plt.gcf ().autofmt_xdate()
f.subplots_adjust(hspace=0)
plt.savefig('102019ines3.png')
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
plt.plot (date82018, temp82018)

# %%
#a1.set_xlim(0,10) aource axis restrictor

# %%
plt.plot (date82018, temp82018)

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False, figsize=(25,25))
ax1.plot(date82018, temp82018, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('August 2018 Time Series')
ax2.plot(date82018, sal82018)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date82018, chl82018, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date82018, cdom82018, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
a1.set_xlim("8/22/2018","8/30/2018") aource axis restrictor
plt.gcf ().autofmt_xdate()
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
# Out:
#   File "<ipython-input-8-ba04e9a5649d>", line 11
#     a1.set_xlim("8/22/2018","8/30/2018") aource axis restrictor
#                                               ^
# SyntaxError: invalid syntax

# %%
#didnt work

# %%
#new line test
#ax.set_xticks([0,2,4,6])
#ax.set_xticklabels(['zero','two','four','six'])

# %%
ax.set_xticks([0,129,258,386,515,644,773,901,1030])
ax.set_xticklabels(['Auugust 22nd','August 23rd','August 24th','August 25th','August 26th','August 27th','August 28th','August 29th','August 30th'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-43ba47045133> in <module>
# ----> 1 ax.set_xticks([0,129,258,386,515,644,773,901,1030])
#       2 ax.set_xticklabels(['Auugust 22nd','August 23rd','August 24th','August 25th','August 26th','August 27th','August 28th','August 29th','August 30th'])
#
# NameError: name 'ax' is not defined

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False, figsize=(25,25))
ax1.plot(date82018, temp82018, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('August 2018 Time Series')
ax2.plot(date82018, sal82018)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date82018, chl82018, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date82018, cdom82018, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
ax1.set_xticks([0,129,258,386,515,644,773,901,1030])
ax1.set_xticklabels(['August 22nd','August 23rd','August 24th','August 25th','August 26th','August 27th','August 28th','August 29th','August 30th'])
plt.gcf ().autofmt_xdate()
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
date82018
# Out:
# 0       2018-08-22 20:05:33.0
# 1       2018-08-22 20:15:34.0
# 2       2018-08-22 20:25:34.0
# 3       2018-08-22 20:35:34.0
# 4       2018-08-22 20:45:34.0
#                 ...
# 1153    2018-08-30 23:09:42.0
# 1154    2018-08-30 23:19:42.0
# 1155    2018-08-30 23:29:42.0
# 1156    2018-08-30 23:39:42.0
# 1157    2018-08-30 23:49:42.0
# Name: date, Length: 1158, dtype: object

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False, figsize=(25,25))
ax1.plot(date82018, temp82018, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('August 2018 Time Series')
ax2.plot(date82018, sal82018)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date82018, chl82018, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date82018, cdom82018, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
date82018.index = pd.to_datetime(date82018['date'])
plt.gcf ().autofmt_xdate()
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-fc047c014f51> in <module>
#       9 ax4.plot(date82018, cdom82018, color='c')
#      10 ax4.legend (["CDOM"], shadow=True, loc = 'best')
# ---> 11 date82018.index = pd.to_datetime(date82018['date'])
#      12 plt.gcf ().autofmt_xdate()
#      13 f.subplots_adjust(hspace=0)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# ...

# %%
type (date82018)
# Out:
# pandas.core.series.Series

# %%
date82018["date"] = pd.to_datetime(date82018["date"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-3c74887b511d> in <module>
# ----> 1 date82018["date"] = pd.to_datetime(date82018["date"])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %% [raw]
# #before the dates were visualized as objects instead of actual date values which is why they showed up the way they did

# %%
date82018 = pd.to_datetime(date82018)

# %%
#this registered the "dates" as actual dates

# %%
print (date82018)
# Out:
# 0      2018-08-22 20:05:33
# 1      2018-08-22 20:15:34
# 2      2018-08-22 20:25:34
# 3      2018-08-22 20:35:34
# 4      2018-08-22 20:45:34
#                ...
# 1153   2018-08-30 23:09:42
# 1154   2018-08-30 23:19:42
# 1155   2018-08-30 23:29:42
# 1156   2018-08-30 23:39:42
# 1157   2018-08-30 23:49:42
# Name: date, Length: 1158, dtype: datetime64[ns]

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False, figsize=(25,25))
ax1.plot(date82018, temp82018, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('August 2018 Time Series')
ax2.plot(date82018, sal82018)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.plot(date82018, chl82018, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.plot(date82018, cdom82018, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
plt.gcf ().autofmt_xdate()
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# %%
#testing format changes

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False, figsize=(25,25))
ax1.plot(date82018, temp82018, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, fontsize = 'large', loc = 'best')
ax1.set_title('August 2018 Time Series')
ax2.plot(date82018, sal82018)
ax2.legend (["Salinity (PGU)"], shadow=True, fontsize = 'large', loc = 'best')
ax3.plot(date82018, chl82018, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, fontsize = 'large', loc = 'best')
ax4.plot(date82018, cdom82018, color='c')
ax4.legend (["CDOM"], shadow=True, fontsize = 'large', loc = 'best')
ax1.grid()
plt.gcf ().autofmt_xdate()
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
