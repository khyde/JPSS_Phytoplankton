# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
data82018 = pd.read_csv ('2018-08.csv')
data112018 = pd.read_csv ('2018-11.csv')
data52019 = pd.read_csv ('2019-05.csv')
data102019 = pd.read_csv ('2019-10.csv')

# %%
data52019
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3200   -71.4210  2019-05-22 19:44:59.0      5      13.4309
# 1      41.2825   -71.4210  2019-05-22 19:55:32.0      5      13.1200
# 2      41.2518   -71.4201  2019-05-22 20:05:33.0      5      13.2860
# 3      41.2210   -71.4198  2019-05-22 20:15:33.0      5      13.4242
# 4      41.1905   -71.4210  2019-05-22 20:25:34.0      5      13.1448
# ...        ...        ...                    ...    ...          ...
# 1081   42.8329   -67.8352  2019-06-02 15:50:31.0      5       9.3813
# 1082   42.8492   -67.8325  2019-06-02 16:00:31.0      5       9.2167
# 1083   42.8787   -67.8265  2019-06-02 16:10:31.0      5       8.9657
# 1084   42.9086   -67.8209  2019-06-02 16:20:31.0      5       9.1003
# 1085   43.4120   -67.7110  2019-06-02 20:15:00.0      5       9.0000
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3542   0.3751  0.0640    2.1672    2.1816          NaN
# ...

# %%
saldata = [data82018.salinity, data112018.salinity, data52019.salinity, data102019.salinity]

# %%
tempdata = [data82018.temperature, data112018.temperature, data52019.temperature, data102019.temperature]

# %%
chldata = [data82018.chl_ctd, data112018.chl_ctd, data52019.chl_ctd, data102019.chl_ctd]

# %%
cdomdata = [data82018.cdom_ctd, data112018.cdom_ctd, data52019.cdom_ctd, data102019.cdom_ctd]

# %%
for element in saldata:
    plt.hist (element)

# %%
for element in saldata:
    plt.hist (element[1])

# %%
for element in saldata:
    plt.hist (element[1, 2, 3, 4])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-0619596d9617> in <module>
#       1 for element in saldata:
# ----> 2     plt.hist (element[1, 2, 3, 4])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
for element in saldata:
    plt.hist (element)
    plt.figure ()

# %%
# the rwidth is meant to squeeze the bars a little so that the differences are observable

# %%
for element in saldata:
    plt.hist (element, color = ['b'], rwidth = 0.95)
    plt.xlabel ("Salinity (PGU)")
    plt.legend (["Salinity (PGU)"])
    plt.figure ()

# %%
for element in tempdata:
    plt.hist (element, color = ['r'], rwidth = 0.95)
    plt.xlabel ("Salinity (PGU)")
    plt.legend (["Salinity (PGU)"])
    plt.figure ()
# Out:
# C:\Users\Barry\anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Barry\anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
for element in chldata:
    plt.hist ( np.log(element), color = ['g'], rwidth = 0.95)
    plt.xlabel ("Chlorophyll (uG/L)")
    plt.legend (["Chlorophyll (uG/L)"])
    plt.figure ()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b49045268b31> in <module>
#       1 for element in chldata:
# ----> 2     plt.hist ( np.log(element), color = ['g'], rwidth = 0.95)
#       3     plt.xlabel ("Chlorophyll (uG/L)")
#       4     plt.legend (["Chlorophyll (uG/L)"])
#       5     plt.figure ()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
for element in cdomdata:
    plt.hist ( np.log(element), color = ['c'], rwidth = 0.95)
    plt.xlabel ("Dissolved Organic Matter")
    plt.legend (["Dissolved Organic Matter"])
    plt.figure ()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-3f854bea7ad4> in <module>
#       1 for element in cdomdata:
# ----> 2     plt.hist ( np.log(element), color = ['c'], rwidth = 0.95)
#       3     plt.xlabel ("Dissolved Organic Matter")
#       4     plt.legend (["Dissolved Organic Matter"])
#       5     plt.figure ()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
df = pd.read_csv ('2019-05.csv')

# %%
df
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3200   -71.4210  2019-05-22 19:44:59.0      5      13.4309
# 1      41.2825   -71.4210  2019-05-22 19:55:32.0      5      13.1200
# 2      41.2518   -71.4201  2019-05-22 20:05:33.0      5      13.2860
# 3      41.2210   -71.4198  2019-05-22 20:15:33.0      5      13.4242
# 4      41.1905   -71.4210  2019-05-22 20:25:34.0      5      13.1448
# ...        ...        ...                    ...    ...          ...
# 1081   42.8329   -67.8352  2019-06-02 15:50:31.0      5       9.3813
# 1082   42.8492   -67.8325  2019-06-02 16:00:31.0      5       9.2167
# 1083   42.8787   -67.8265  2019-06-02 16:10:31.0      5       8.9657
# 1084   42.9086   -67.8209  2019-06-02 16:20:31.0      5       9.1003
# 1085   43.4120   -67.7110  2019-06-02 20:15:00.0      5       9.0000
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3542   0.3751  0.0640    2.1672    2.1816          NaN
# ...

# %%
data52019 = pd.read_csv ('2019-05.csv', na_values = ["0.3751"])

# %%
data52019
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3200   -71.4210  2019-05-22 19:44:59.0      5      13.4309
# 1      41.2825   -71.4210  2019-05-22 19:55:32.0      5      13.1200
# 2      41.2518   -71.4201  2019-05-22 20:05:33.0      5      13.2860
# 3      41.2210   -71.4198  2019-05-22 20:15:33.0      5      13.4242
# 4      41.1905   -71.4210  2019-05-22 20:25:34.0      5      13.1448
# ...        ...        ...                    ...    ...          ...
# 1081   42.8329   -67.8352  2019-06-02 15:50:31.0      5       9.3813
# 1082   42.8492   -67.8325  2019-06-02 16:00:31.0      5       9.2167
# 1083   42.8787   -67.8265  2019-06-02 16:10:31.0      5       8.9657
# 1084   42.9086   -67.8209  2019-06-02 16:20:31.0      5       9.1003
# 1085   43.4120   -67.7110  2019-06-02 20:15:00.0      5       9.0000
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3542      NaN  0.0640    2.1672    2.1816          NaN
# ...

# %%
data52019 = pd.read_csv ('2019-05.csv', na_values = {
    'eps' : ["not available"],
    'revenue' : ["not available", "-1"]
    'people' : ["not available"]
})
# Out:
#   File "<ipython-input-24-139c22c5f64b>", line 4
#     'people' : ["not available"]
#            ^
# SyntaxError: invalid syntax

# %%
data52019 = pd.read_csv ('2019-05.csv', na_values = {
    'chl_ctd' : ["-0"]
})

# %%
data52019
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3200   -71.4210  2019-05-22 19:44:59.0      5      13.4309
# 1      41.2825   -71.4210  2019-05-22 19:55:32.0      5      13.1200
# 2      41.2518   -71.4201  2019-05-22 20:05:33.0      5      13.2860
# 3      41.2210   -71.4198  2019-05-22 20:15:33.0      5      13.4242
# 4      41.1905   -71.4210  2019-05-22 20:25:34.0      5      13.1448
# ...        ...        ...                    ...    ...          ...
# 1081   42.8329   -67.8352  2019-06-02 15:50:31.0      5       9.3813
# 1082   42.8492   -67.8325  2019-06-02 16:00:31.0      5       9.2167
# 1083   42.8787   -67.8265  2019-06-02 16:10:31.0      5       8.9657
# 1084   42.9086   -67.8209  2019-06-02 16:20:31.0      5       9.1003
# 1085   43.4120   -67.7110  2019-06-02 20:15:00.0      5       9.0000
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3542   0.3751  0.0640    2.1672    2.1816          NaN
# ...

# %%
data52019.isnull ()
# Out:
#       latitude  longitude   date  depth  temperature  salinity  chl_ctd  \
# 0        False      False  False  False        False     False    False
# 1        False      False  False  False        False     False    False
# 2        False      False  False  False        False     False    False
# 3        False      False  False  False        False     False    False
# 4        False      False  False  False        False     False    False
# ...        ...        ...    ...    ...          ...       ...      ...
# 1081     False      False  False  False        False     False    False
# 1082     False      False  False  False        False     False    False
# 1083     False      False  False  False        False     False    False
# 1084     False      False  False  False        False     False    False
# 1085     False      False  False  False        False     False    False
#
#       pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      False     False     False         True
# ...

# %%
data52019.is < 0 ()
# Out:
#   File "<ipython-input-29-516878f5e61a>", line 1
#     data52019.is < 0 ()
#                ^
# SyntaxError: invalid syntax

# %%
for cols in data52019.chl_ctd:
    plt.hist (cols > 0)
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
plt.hist (data52019.chl_ctd)
# Out:
# C:\Users\Barry\anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Barry\anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([828.,  78.,  16.,  11.,   5.,   1.,   1.,   4.,   0.,   1.]),
#  array([-0.2057 ,  0.78787,  1.78144,  2.77501,  3.76858,  4.76215,
#          5.75572,  6.74929,  7.74286,  8.73643,  9.73   ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist (data82018.chl_ctd)
# Out:
# (array([692., 253., 100.,  24.,   4.,  13.,  22.,   5.,   2.,   1.]),
#  array([0.0665 , 0.42685, 0.7872 , 1.14755, 1.5079 , 1.86825, 2.2286 ,
#         2.58895, 2.9493 , 3.30965, 3.67   ]),
#  <a list of 10 Patch objects>)

# %%
pd.read_csv ('2019-05')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-5135b812d558> in <module>
# ----> 1 pd.read_csv ('2019-05')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
# ...

# %%
data52019
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3200   -71.4210  2019-05-22 19:44:59.0      5      13.4309
# 1      41.2825   -71.4210  2019-05-22 19:55:32.0      5      13.1200
# 2      41.2518   -71.4201  2019-05-22 20:05:33.0      5      13.2860
# 3      41.2210   -71.4198  2019-05-22 20:15:33.0      5      13.4242
# 4      41.1905   -71.4210  2019-05-22 20:25:34.0      5      13.1448
# ...        ...        ...                    ...    ...          ...
# 1081   42.8329   -67.8352  2019-06-02 15:50:31.0      5       9.3813
# 1082   42.8492   -67.8325  2019-06-02 16:00:31.0      5       9.2167
# 1083   42.8787   -67.8265  2019-06-02 16:10:31.0      5       8.9657
# 1084   42.9086   -67.8209  2019-06-02 16:20:31.0      5       9.1003
# 1085   43.4120   -67.7110  2019-06-02 20:15:00.0      5       9.0000
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3542   0.3751  0.0640    2.1672    2.1816          NaN
# ...

# %%
data52019 (cols > 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-b661a7f7c461> in <module>
# ----> 1 data52019 (cols > 0)
#
# TypeError: 'DataFrame' object is not callable

# %%
data52019 (columns = ['date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-ae17a6f0d993> in <module>
# ----> 1 data52019 (columns = ['date'])
#
# TypeError: 'DataFrame' object is not callable

# %%
data52019.chl_ctd (cols > 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-f7bbd6ef2e9f> in <module>
# ----> 1 data52019.chl_ctd (cols > 0)
#
# TypeError: 'Series' object is not callable

# %% [markdown]
# data52019

# %%
data52019
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3200   -71.4210  2019-05-22 19:44:59.0      5      13.4309
# 1      41.2825   -71.4210  2019-05-22 19:55:32.0      5      13.1200
# 2      41.2518   -71.4201  2019-05-22 20:05:33.0      5      13.2860
# 3      41.2210   -71.4198  2019-05-22 20:15:33.0      5      13.4242
# 4      41.1905   -71.4210  2019-05-22 20:25:34.0      5      13.1448
# ...        ...        ...                    ...    ...          ...
# 1081   42.8329   -67.8352  2019-06-02 15:50:31.0      5       9.3813
# 1082   42.8492   -67.8325  2019-06-02 16:00:31.0      5       9.2167
# 1083   42.8787   -67.8265  2019-06-02 16:10:31.0      5       8.9657
# 1084   42.9086   -67.8209  2019-06-02 16:20:31.0      5       9.1003
# 1085   43.4120   -67.7110  2019-06-02 20:15:00.0      5       9.0000
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3542   0.3751  0.0640    2.1672    2.1816          NaN
# ...

# %%
data52019.chl_ctd
# Out:
# 0       0.3751
# 1       0.4053
# 2       0.3267
# 3       0.4295
# 4       0.4114
#          ...
# 1081   -0.0302
# 1082    0.0060
# 1083    0.0121
# 1084    0.0060
# 1085    9.7300
# Name: chl_ctd, Length: 1086, dtype: float64

# %%
data52019.chl_ctd > 0
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1081    False
# 1082     True
# 1083     True
# 1084     True
# 1085     True
# Name: chl_ctd, Length: 1086, dtype: bool

# %%
print (data52019)
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3200   -71.4210  2019-05-22 19:44:59.0      5      13.4309
# 1      41.2825   -71.4210  2019-05-22 19:55:32.0      5      13.1200
# 2      41.2518   -71.4201  2019-05-22 20:05:33.0      5      13.2860
# 3      41.2210   -71.4198  2019-05-22 20:15:33.0      5      13.4242
# 4      41.1905   -71.4210  2019-05-22 20:25:34.0      5      13.1448
# ...        ...        ...                    ...    ...          ...
# 1081   42.8329   -67.8352  2019-06-02 15:50:31.0      5       9.3813
# 1082   42.8492   -67.8325  2019-06-02 16:00:31.0      5       9.2167
# 1083   42.8787   -67.8265  2019-06-02 16:10:31.0      5       8.9657
# 1084   42.9086   -67.8209  2019-06-02 16:20:31.0      5       9.1003
# 1085   43.4120   -67.7110  2019-06-02 20:15:00.0      5       9.0000
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3542   0.3751  0.0640    2.1672    2.1816          NaN
# ...

# %%
data52019 = np.genfromcsv('2019-05.csv',delimiter=' ')
print(data52019)
print(type(data52019[0][0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-8efccdd4882f> in <module>
# ----> 1 data52019 = np.genfromcsv('2019-05.csv',delimiter=' ')
#       2 print(data52019)
#       3 print(type(data52019[0][0]))
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     218             else:
#     219                 raise AttributeError("module {!r} has no attribute "
# --> 220                                      "{!r}".format(__name__, attr))
#     221
#     222         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'genfromcsv'

# %%
data52019
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3200   -71.4210  2019-05-22 19:44:59.0      5      13.4309
# 1      41.2825   -71.4210  2019-05-22 19:55:32.0      5      13.1200
# 2      41.2518   -71.4201  2019-05-22 20:05:33.0      5      13.2860
# 3      41.2210   -71.4198  2019-05-22 20:15:33.0      5      13.4242
# 4      41.1905   -71.4210  2019-05-22 20:25:34.0      5      13.1448
# ...        ...        ...                    ...    ...          ...
# 1081   42.8329   -67.8352  2019-06-02 15:50:31.0      5       9.3813
# 1082   42.8492   -67.8325  2019-06-02 16:00:31.0      5       9.2167
# 1083   42.8787   -67.8265  2019-06-02 16:10:31.0      5       8.9657
# 1084   42.9086   -67.8209  2019-06-02 16:20:31.0      5       9.1003
# 1085   43.4120   -67.7110  2019-06-02 20:15:00.0      5       9.0000
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3542   0.3751  0.0640    2.1672    2.1816          NaN
# ...

# %%
print (data52019)
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3200   -71.4210  2019-05-22 19:44:59.0      5      13.4309
# 1      41.2825   -71.4210  2019-05-22 19:55:32.0      5      13.1200
# 2      41.2518   -71.4201  2019-05-22 20:05:33.0      5      13.2860
# 3      41.2210   -71.4198  2019-05-22 20:15:33.0      5      13.4242
# 4      41.1905   -71.4210  2019-05-22 20:25:34.0      5      13.1448
# ...        ...        ...                    ...    ...          ...
# 1081   42.8329   -67.8352  2019-06-02 15:50:31.0      5       9.3813
# 1082   42.8492   -67.8325  2019-06-02 16:00:31.0      5       9.2167
# 1083   42.8787   -67.8265  2019-06-02 16:10:31.0      5       8.9657
# 1084   42.9086   -67.8209  2019-06-02 16:20:31.0      5       9.1003
# 1085   43.4120   -67.7110  2019-06-02 20:15:00.0      5       9.0000
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3542   0.3751  0.0640    2.1672    2.1816          NaN
# ...

# %%
for element in cdomdata:
    plt.hist ( np.log(element), color = ['c'], rwidth = 0.95)
    plt.xlabel ("Dissolved Organic Matter")
    plt.legend (["Dissolved Organic Matter"])
    plt.figure ()
# Out:
# C:\Users\Barry\anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Barry\anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# C:\Users\Barry\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Barry\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-3f854bea7ad4> in <module>
#       1 for element in cdomdata:
# ----> 2     plt.hist ( np.log(element), color = ['c'], rwidth = 0.95)
# ...

# %%
for element in cdomdata:
    plt.hist ( np.log(element), color = ['c'], rwidth = 0.95)
    plt.figure ()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-5cb09a875851> in <module>
#       1 for element in cdomdata:
# ----> 2     plt.hist ( np.log(element), color = ['c'], rwidth = 0.95)
#       3     plt.figure ()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# ...

# %%
for element[element > 0] in cdomdata:
    plt.hist ( np.log(element), color = ['c'], rwidth = 0.95)
    plt.xlabel ("Dissolved Organic Matter")
    plt.legend (["Dissolved Organic Matter"])
    plt.figure ()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-8b80a6fec2b5> in <module>
#       1 for element[element > 0] in cdomdata:
# ----> 2     plt.hist ( np.log(element), color = ['c'], rwidth = 0.95)
#       3     plt.xlabel ("Dissolved Organic Matter")
#       4     plt.legend (["Dissolved Organic Matter"])
#       5     plt.figure ()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# ...

# %%
for element in cdomdata:
    print (element.info)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-a38be8abc54f> in <module>
#       1 for element in cdomdata:
# ----> 2     print (element.info)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
for element in cdomdata:
    plt.hist ( np.log(element), color = ['c'], rwidth = 0.95)
    plt.figure ()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-5cb09a875851> in <module>
#       1 for element in cdomdata:
# ----> 2     plt.hist ( np.log(element), color = ['c'], rwidth = 0.95)
#       3     plt.figure ()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# ...

# %%
for element.loc [element > 0] in cdomdata:
    type (element)

# %%
for element.loc[element[:]> 0] in cdomdata:
    plt.hist ( np.log(element), color = ['c'], rwidth = 0.95)
    plt.figure ()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-1f084488d628> in <module>
#       1 for element.loc[element[:]> 0] in cdomdata:
# ----> 2     plt.hist ( np.log(element), color = ['c'], rwidth = 0.95)
#       3     plt.figure ()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# ...

# %%
for element in cdomdata:
    plt.hist ( np.log(element.loc[element > 0]), color = ['c'], rwidth = 0.95)
    plt.xlabel ("Dissolved Organic Matter")
    plt.legend (["Dissolved Organic Matter"])
    plt.figure ()

# %%
for element in chldata:
    plt.hist ( np.log(element.loc[element > 0]), color = ['g'], rwidth = 0.95)
    plt.xlabel ("Chlorophyll (uG/L)")
    plt.legend (["Chlorophyll (uG/L)"])
    plt.figure ()

# %%
for element in saldata:
    plt.hist (element, color = ['b'], rwidth = 0.95)
    plt.xlabel ("Salinity (PGU)")
    plt.legend (["Salinity (PGU)"])
    plt.figure ()

# %%
for element in tempdata:
    plt.hist (element, color = ['r'], rwidth = 0.95)
    plt.xlabel ("Salinity (PGU)")
    plt.legend (["Salinity (PGU)"])
    plt.figure ()

# %%
for element in chldata:
    plt.hist ( np.log(element.loc[element > 0]), color = ['g'], rwidth = 0.95)
    plt.xlabel ("Chlorophyll (uG/L)")
    plt.legend (["Chlorophyll (uG/L)"])
    plt.figure ()

# %%
for element in cdomdata:
    plt.hist ( np.log(element.loc[element > 0]), color = ['c'], rwidth = 0.95)
    plt.xlabel ("Dissolved Organic Matter")
    plt.legend (["Dissolved Organic Matter"])
    plt.figure ()

# %%
# accidentally deleted

# %%
salfunction
# Out:
# <function __main__.salfunction()>

# %%
salfunction ()

# %%
def tempfunction ():
    for element in tempdata:
        plt.hist (element, color = ['r'], rwidth = 0.95)
        plt.xlabel ("Salinity (PGU)")
        plt.legend (["Salinity (PGU)"])
        plt.figure ()

# %%
tempfunction ()

# %%
def chlfunction ():
    for element in chldata:
        plt.hist ( np.log(element.loc[element > 0]), color = ['g'], rwidth = 0.95)
        plt.xlabel ("Chlorophyll (uG/L)")
        plt.legend (["Chlorophyll (uG/L)"])
        plt.figure ()

# %%
chlfunction ()

# %%
def cdomfunction ():
    for element in cdomdata:
        plt.hist ( np.log(element.loc[element > 0]), color = ['c'], rwidth = 0.95)
        plt.xlabel ("Dissolved Organic Matter")
        plt.legend (["Dissolved Organic Matter"])
        plt.figure ()

# %%
cdomfunction ():
# Out:
#   File "<ipython-input-86-27021f37fe17>", line 1
#     cdomfunction ():
#                     ^
# SyntaxError: invalid syntax

# %%
cdomfunction ()

# %%
# pure stack overflow

# %%
# Four axes, returned as a 2-d array
f, axarr = plt.subplots(2, 2)
axarr[0, 0].plot(x, y)
axarr[0, 0].set_title('Axis [0,0]')
axarr[0, 1].scatter(x, y)
axarr[0, 1].set_title('Axis [0,1]')
axarr[1, 0].plot(x, y ** 2)
axarr[1, 0].set_title('Axis [1,0]')
axarr[1, 1].scatter(x, y ** 2)
axarr[1, 1].set_title('Axis [1,1]')
# Fine-tune figure; hide x ticks for top plots and y ticks for right plots
plt.setp([a.get_xticklabels() for a in axarr[0, :]], visible=False)
plt.setp([a.get_yticklabels() for a in axarr[:, 1]], visible=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-49eaec0c5b38> in <module>
#       1 # Four axes, returned as a 2-d array
#       2 f, axarr = plt.subplots(2, 2)
# ----> 3 axarr[0, 0].plot(x, y)
#       4 axarr[0, 0].set_title('Axis [0,0]')
#       5 axarr[0, 1].scatter(x, y)
#
# NameError: name 'x' is not defined

# %%
date82018 = data82018.date
temp82018 = data82018.temperature
sal82018 = data82018.salinity
chl82018 = data82018.chl_ctd
cdom82018 = data82018.cdom_ctd

date112018 = data112018.date
temp112018 = data112018.temperature
sal112018 = data112018.salinity
chl112018 = data112018.chl_ctd
cdom112018 = data112018.cdom_ctd

date52019 = data52019.date
temp52019 = data52019.temperature
sal52019 = data52019.salinity
chl52019 = data52019.chl_ctd
cdom52019 = data52019.cdom_ctd

date102019 = data102019.date
temp102019 = data102019.temperature
sal102019 = data102019.salinity
chl102019 = data102019.chl_ctd
cdom102019 = data102019.cdom_ctd

# %%
f, axarr = plt.subplots(2, 2)
ax1.plot(sal82018, temp82018)
ax1.set_title('Axis [0,0]')
ax2.scatter(sal82018, temp82018)
ax2.set_title('Axis [0,1]')
ax3.plot(sal82018, temp82018 ** 2)
axarr.set_title('Axis [1,0]')
axarr.scatter(sal82018, temp82018 ** 2)
axarr.set_title('Axis [1,1]')
plt.setp([a.get_xticklabels() for a in axarr[0, :]], visible=False)
plt.setp([a.get_yticklabels() for a in axarr[:, 1]], visible=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-18756cd2c337> in <module>
#       1 f, axarr = plt.subplots(2, 2)
# ----> 2 axarr.plot(sal82018, temp82018)
#       3 axarr.set_title('Axis [0,0]')
#       4 axarr.scatter(sal82018, temp82018)
#       5 axarr.set_title('Axis [0,1]')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(2,2)
ax1.hist(temp52019, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('May 2019 Time Series')
ax2.hist(sal52019)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
ax3.hist(chl52019, color='g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, loc = 'best')
ax4.hist(cdom52019, color='c')
ax4.legend (["CDOM"], shadow=True, loc = 'best')
f.subplots_adjust(hspace=0)
plt.savefig('52019lines1.png')
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-37d227057a86> in <module>
# ----> 1 f, (ax1, ax2, ax3, ax4) = plt.subplots(2,2)
#       2 ax1.hist(temp52019, color='r')
#       3 ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
#       4 ax1.set_title('May 2019 Time Series')
#       5 ax2.hist(sal52019)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
f, (ax1, ax2) = plt.subplots(2,2)
ax1.hist(temp52019, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
ax1.set_title('May 2019 Time Series')
ax2.hist(sal52019)
ax2.legend (["Salinity (PGU)"], shadow=True, loc = 'best')
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-fa8971f1b328> in <module>
#       1 f, (ax1, ax2) = plt.subplots(2,2)
# ----> 2 ax1.hist(temp52019, color='r')
#       3 ax1.legend (["Temperature (°C)"], shadow=True, loc = 'best')
#       4 ax1.set_title('May 2019 Time Series')
#       5 ax2.hist(sal52019)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'hist'
