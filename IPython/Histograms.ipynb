# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
82018 = pd.read_csv ('2018-08.csv')
# Out:
#   File "<ipython-input-2-8ee3d9f3bd41>", line 1
#     82018 = pd.read_csv ('2018-08.csv')
#                                        ^
# SyntaxError: can't assign to literal

# %%
data82018 = pd.read_csv ('2018-08.csv')

# %%
data112018 = pd.read_csv ('2018-11.csv')

# %%
data52019 = pd.read_csv ('2019-05.csv')

# %%
data102019 = pd.read_csv ('2019-10.csv')

# %%
data82018
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3639   -71.4220  2018-08-22 20:05:33.0      4      22.9616
# 1      41.3397   -71.4215  2018-08-22 20:15:34.0      4      22.9605
# 2      41.3143   -71.4218  2018-08-22 20:25:34.0      4      22.8414
# 3      41.2886   -71.4227  2018-08-22 20:35:34.0      4      22.6832
# 4      41.2631   -71.4226  2018-08-22 20:45:34.0      4      22.2266
# ...        ...        ...                    ...    ...          ...
# 1153   36.6353   -75.0009  2018-08-30 23:09:42.0      4      27.3766
# 1154   36.6121   -75.0006  2018-08-30 23:19:42.0      4      27.3393
# 1155   36.5841   -75.0000  2018-08-30 23:29:42.0      4      27.5079
# 1156   36.5565   -75.0001  2018-08-30 23:39:42.0      4      27.5168
# 1157   36.5290   -75.0004  2018-08-30 23:49:42.0      4      27.6020
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3731   3.0008  0.1708    2.2575    6.0672          NaN
# ...

# %%
plt.hist (data82018.salinity, data112018.salinity)
plt.title ('2018 Salinity Variability Non-log Normalized)')
plt.legend (data82018.salinity, data112018.salinity)
plt.show ()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-c4bd215b91c7> in <module>
# ----> 1 plt.hist (data82018.salinity, data112018.salinity)
#       2 plt.title ('2018 Salinity Variability Non-log Normalized)')
#       3 plt.legend (data82018.salinity, data112018.salinity)
#       4 plt.show ()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
plt.hist (data82018.salinity)
plt.title ('2018 Salinity Variability Non-log Normalized)')
plt.legend (data82018.salinity)
plt.show ()

# %%
plt.hist (data82018.salinity, data112018.salinity)
plt.title ('2018 Salinity Variability Non-log Normalized)')
plt.legend (data82018.salinity, data112018.salinity)
plt.show ()

# %%
plt.hist (data82018.salinity)
plt.title ('2018 Salinity Variability Non-log Normalized)')
plt.legend ('Salinity 08-2018')
plt.show ()

# %%
plt.hist (data82018.salinity)
plt.title ('2018 Salinity Variability Non-log Normalized)')
plt.legend ('08-2018')
plt.show ()

# %%
plt.hist (np.log (data82018.salinity), color = ['r'], rwidth = 0.95)
plt.xlabel ("Salinity (PGU)")
plt.title ('August 2018 Lognormalized Salinity Variability')
plt.legend (["Salinity (PGU)"])
plt.show ()

# %%
plt.hist (np.log (data82018.salinity), color = ['r'], rwidth = 0.95)
plt.xlabel ("Salinity (PGU)")
plt.title ('August 2018 Lognormalized Salinity Variability')
plt.legend (["Salinity (PGU)"])
plt.show ()

# %%
plt.hist (np.log (data82018.salinity), color = ['b'], rwidth = 0.95)
plt.xlabel ("Salinity (PGU)")
plt.title ('August 2018 Lognormalized Salinity Variability')
plt.legend (["Salinity (PGU)"])
plt.show ()

# %%
plt.hist (data82018.temperature, color = ['r'], rwidth = 0.95)
plt.xlabel ("Temperature (Celsius)")
plt.title ('August 2018 Non-Log Normalized Temperature Variability')
plt.legend (["Temperature (Celsius)"])
plt.show ()

# %%
plt.hist (np.log (data82018.temperature), color = ['r'], rwidth = 0.95)
plt.xlabel ("Temperature (Celsius)")
plt.title ('August 2018 Lognormalized Temperature Variability')
plt.legend (["Temperature (Celsius)"])
plt.show ()

# %%
plt.hist (data82018.chl_ctd, color = ['g'], rwidth = 0.95)
plt.xlabel ("Chlorophyll (uG/L)")
plt.title ('August 2018 Non-Log Normalized Chlorophyll Variability')
plt.legend (["Chlorophyll (uG/L)"])
plt.show ()
# Out:
# C:\Users\Barry\anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Barry\anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.hist (np.log (data82018.chl_ctd), color = ['g'], rwidth = 0.95)
plt.xlabel ("Chlorophyll (uG/L)")
plt.title ('August 2018 Lognormalized Chlorophyll Variability')
plt.legend (["Chlorophyll (uG/L)"])
plt.show ()

# %%
plt.hist (data82018.cdom_ctd, color = ['c'], rwidth = 0.95)
plt.xlabel ("Dissolved Organic Matter")
plt.title ('August 2018 Non-Log Normalized Dissolved Organic Matter Variability')
plt.legend (["Dissolved Organic Matter"])
plt.show ()

# %%
plt.hist (np.log (data82018.cdom_ctd), color = ['c'], rwidth = 0.95)
plt.xlabel ("Dissolved Organic Matter")
plt.title ('August 2018 Lognormalized Dissolved Organic Matter Variability')
plt.legend (["Dissolved Organic Matter"])
plt.show ()

# %%
plt.hist (data112018.salinity, color = ['b'], rwidth = 0.95)
plt.xlabel ("Salinity (PGU)")
plt.title ('November 2018 Non-Log normalized Salinity Variability')
plt.legend (["Salinity (PGU)"])
plt.show ()

plt.hist (np.log (data112018.salinity), color = ['b'], rwidth = 0.95)
plt.xlabel ("Salinity (PGU)")
plt.title ('November 2018 Lognormalized Salinity Variability')
plt.legend (["Salinity (PGU)"])
plt.show ()

# %%
plt.hist (data112018.temperature, color = ['r'], rwidth = 0.95)
plt.xlabel ("Temperature (Celsius)")
plt.title ('November 2018 Non-Log Normalized Temperature Variability')
plt.legend (["Temperature (Celsius)"])
plt.show ()

plt.hist (np.log (data112018.temperature), color = ['r'], rwidth = 0.95)
plt.xlabel ("Temperature (Celsius)")
plt.title ('November 2018 Lognormalized Temperature Variability')
plt.legend (["Temperature (Celsius)"])
plt.show ()

# %%
plt.hist (data112018.chl_ctd, color = ['g'], rwidth = 0.95)
plt.xlabel ("Chlorophyll (uG/L)")
plt.title ('November 2018 Non-Log Normalized Chlorophyll Variability')
plt.legend (["Chlorophyll (uG/L)"])
plt.show ()

plt.hist (np.log (data112018.chl_ctd), color = ['g'], rwidth = 0.95)
plt.xlabel ("Chlorophyll (uG/L)")
plt.title ('November 2018 Lognormalized Chlorophyll Variability')
plt.legend (["Chlorophyll (uG/L)"])
plt.show ()

# %%
plt.hist (data112018.cdom_ctd, color = ['c'], rwidth = 0.95)
plt.xlabel ("Dissolved Organic Matter")
plt.title ('November 2018 Non-Log Normalized Dissolved Organic Matter Variability')
plt.legend (["Dissolved Organic Matter"])
plt.show ()

plt.hist (np.log (data112018.cdom_ctd), color = ['c'], rwidth = 0.95)
plt.xlabel ("Dissolved Organic Matter")
plt.title ('November 2018 Lognormalized Dissolved Organic Matter Variability')
plt.legend (["Dissolved Organic Matter"])
plt.show ()

# %%
plt.hist (data52019.salinity, color = ['b'], rwidth = 0.95)
plt.xlabel ("Salinity (PGU)")
plt.title ('May 2019 Non-Log normalized Salinity Variability')
plt.legend (["Salinity (PGU)"])
plt.show ()

plt.hist (np.log (data52019.salinity), color = ['b'], rwidth = 0.95)
plt.xlabel ("Salinity (PGU)")
plt.title ('May 2019 Lognormalized Salinity Variability')
plt.legend (["Salinity (PGU)"])
plt.show ()

plt.hist (data52019.temperature, color = ['r'], rwidth = 0.95)
plt.xlabel ("Temperature (Celsius)")
plt.title ('May 2019 Non-Log Normalized Temperature Variability')
plt.legend (["Temperature (Celsius)"])
plt.show ()

plt.hist (np.log (data52019.temperature), color = ['r'], rwidth = 0.95)
plt.xlabel ("Temperature (Celsius)")
plt.title ('May 2019 Lognormalized Temperature Variability')
plt.legend (["Temperature (Celsius)"])
plt.show ()

plt.hist (data52019.chl_ctd, color = ['g'], rwidth = 0.95)
plt.xlabel ("Chlorophyll (uG/L)")
plt.title ('May 2019 Non-Log Normalized Chlorophyll Variability')
plt.legend (["Chlorophyll (uG/L)"])
plt.show ()

plt.hist (np.log (data52019.chl_ctd), color = ['g'], rwidth = 0.95)
plt.xlabel ("Chlorophyll (uG/L)")
plt.title ('May 2019 Lognormalized Chlorophyll Variability')
plt.legend (["Chlorophyll (uG/L)"])
plt.show ()

plt.hist (data52019.cdom_ctd, color = ['c'], rwidth = 0.95)
plt.xlabel ("Dissolved Organic Matter")
plt.title ('May 2019 Non-Log Normalized Dissolved Organic Matter Variability')
plt.legend (["Dissolved Organic Matter"])
plt.show ()

plt.hist (np.log (data52019.cdom_ctd), color = ['c'], rwidth = 0.95)
plt.xlabel ("Dissolved Organic Matter")
plt.title ('May 2019 Lognormalized Dissolved Organic Matter Variability')
plt.legend (["Dissolved Organic Matter"])
plt.show ()
# Out:
# C:\Users\Barry\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Barry\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-8c4660e8e4c7> in <module>
#      29 plt.show ()
#      30
# ---> 31 plt.hist (np.log (data52019.chl_ctd), color = ['g'], rwidth = 0.95)
#      32 plt.xlabel ("Chlorophyll (uG/L)")
#      33 plt.title ('May 2019 Lognormalized Chlorophyll Variability')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
# ...

# %%
plt.hist (data52019.cdom_ctd, color = ['c'], rwidth = 0.95)
plt.xlabel ("Dissolved Organic Matter")
plt.title ('May 2019 Non-Log Normalized Dissolved Organic Matter Variability')
plt.legend (["Dissolved Organic Matter"])
plt.show ()

plt.hist (np.log (data52019.cdom_ctd), color = ['c'], rwidth = 0.95)
plt.xlabel ("Dissolved Organic Matter")
plt.title ('May 2019 Lognormalized Dissolved Organic Matter Variability')
plt.legend (["Dissolved Organic Matter"])
plt.show ()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-c0e2748db93e> in <module>
#       5 plt.show ()
#       6
# ----> 7 plt.hist (np.log (data52019.cdom_ctd), color = ['c'], rwidth = 0.95)
#       8 plt.xlabel ("Dissolved Organic Matter")
#       9 plt.title ('May 2019 Lognormalized Dissolved Organic Matter Variability')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
#I will need to go back through the data since there appear to be the same hiccups found in GIS

# %%
plt.hist (data102019.salinity, color = ['b'], rwidth = 0.95)
plt.xlabel ("Salinity (PGU)")
plt.title ('October 2019 Non-Log normalized Salinity Variability')
plt.legend (["Salinity (PGU)"])
plt.show ()

plt.hist (np.log (data102019.salinity), color = ['b'], rwidth = 0.95)
plt.xlabel ("Salinity (PGU)")
plt.title ('October 2019 Lognormalized Salinity Variability')
plt.legend (["Salinity (PGU)"])
plt.show ()

plt.hist (data102019.temperature, color = ['r'], rwidth = 0.95)
plt.xlabel ("Temperature (Celsius)")
plt.title ('October 2019 Non-Log Normalized Temperature Variability')
plt.legend (["Temperature (Celsius)"])
plt.show ()

plt.hist (np.log (data102019.temperature), color = ['r'], rwidth = 0.95)
plt.xlabel ("Temperature (Celsius)")
plt.title ('October 2019 Lognormalized Temperature Variability')
plt.legend (["Temperature (Celsius)"])
plt.show ()

plt.hist (data102019.chl_ctd, color = ['g'], rwidth = 0.95)
plt.xlabel ("Chlorophyll (uG/L)")
plt.title ('October 2019 Non-Log Normalized Chlorophyll Variability')
plt.legend (["Chlorophyll (uG/L)"])
plt.show ()

plt.hist (np.log (data102019.chl_ctd), color = ['g'], rwidth = 0.95)
plt.xlabel ("Chlorophyll (uG/L)")
plt.title ('October 2019 Lognormalized Chlorophyll Variability')
plt.legend (["Chlorophyll (uG/L)"])
plt.show ()

plt.hist (data102019.cdom_ctd, color = ['c'], rwidth = 0.95)
plt.xlabel ("Dissolved Organic Matter")
plt.title ('October 2019 Non-Log Normalized Dissolved Organic Matter Variability')
plt.legend (["Dissolved Organic Matter"])
plt.show ()

plt.hist (np.log (data102019.cdom_ctd), color = ['c'], rwidth = 0.95)
plt.xlabel ("Dissolved Organic Matter")
plt.title ('October 2019 Lognormalized Dissolved Organic Matter Variability')
plt.legend (["Dissolved Organic Matter"])
plt.show ()

# %%
plt.hist (data52019.chl_ctd, color = ['g'], rwidth = 0.95)
plt.xlabel ("Chlorophyll (uG/L)")
plt.title ('May 2019 Non-Log Normalized Chlorophyll Variability')
plt.legend (["Chlorophyll (uG/L)"])
plt.show ()

plt.hist (np.log (data52019.chl_ctd), color = ['g'], rwidth = 0.95)
plt.xlabel ("Chlorophyll (uG/L)")
plt.title ('May 2019 Lognormalized Chlorophyll Variability')
plt.legend (["Chlorophyll (uG/L)"])
plt.show ()
# Out:
# C:\Users\Barry\anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Barry\anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# C:\Users\Barry\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Barry\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-4c6a9b7ba6a9> in <module>
#       5 plt.show ()
#       6
# ----> 7 plt.hist (np.log (data52019.chl_ctd), color = ['g'], rwidth = 0.95)
# ...

# %%
plt.hist (data52019.chl_ctd, color = ['g'], rwidth = 0.95)
plt.xlabel ("Chlorophyll (uG/L)")
plt.title ('May 2019 Non-Log Normalized Chlorophyll Variability')
plt.legend (["Chlorophyll (uG/L)"])
plt.show ()

# %%
data52019.chl_ctd
for item in data52019.chl_ctd: 
    if item > 0:
# Out:
#   File "<ipython-input-19-1f98a71c77d9>", line 3
#     if item > 0:
#                  ^
# SyntaxError: unexpected EOF while parsing

# %%
#where the blank space thing will come in handy

# %%
data52019.chl_ctd
if data52019 > 0
# Out:
#   File "<ipython-input-21-676249f06955>", line 2
#     if data52019 > 0
#                     ^
# SyntaxError: invalid syntax

# %%
data82018 = pd.read_csv ('2018-08.csv')

# %%
filtereddata52019 = (line for line in data52019.chl_ctd if not line.startswith('-'))
for line in filtereddata52019:
# Out:
#   File "<ipython-input-22-a61a4cdd28db>", line 2
#     for line in filtereddata52019:
#                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
data52019
# Out:
#       latitude  longitude                   date  depth  temperature  \
# 0      41.3200   -71.4210  2019-05-22 19:44:59.0      5      13.4309
# 1      41.2825   -71.4210  2019-05-22 19:55:32.0      5      13.1200
# 2      41.2518   -71.4201  2019-05-22 20:05:33.0      5      13.2860
# 3      41.2210   -71.4198  2019-05-22 20:15:33.0      5      13.4242
# 4      41.1905   -71.4210  2019-05-22 20:25:34.0      5      13.1448
# ...        ...        ...                    ...    ...          ...
# 1081   42.8329   -67.8352  2019-06-02 15:50:31.0      5       9.3813
# 1082   42.8492   -67.8325  2019-06-02 16:00:31.0      5       9.2167
# 1083   42.8787   -67.8265  2019-06-02 16:10:31.0      5       8.9657
# 1084   42.9086   -67.8209  2019-06-02 16:20:31.0      5       9.1003
# 1085   43.4120   -67.7110  2019-06-02 20:15:00.0      5       9.0000
#
#       salinity  chl_ctd  pc_ctd  cdom_ctd  chl_a676  Unnamed: 10
# 0      31.3542   0.3751  0.0640    2.1672    2.1816          NaN
# ...

# %%
data52019
for number in data52019
    if number > 0
# Out:
#   File "<ipython-input-25-3469704577ff>", line 2
#     for number in data52019
#                            ^
# SyntaxError: invalid syntax

# %%
def read_data (filename)
f = open("2019-05.csv", "rt")
for line in f:
    if line > 0
# Out:
#   File "<ipython-input-28-ec788531a0b3>", line 1
#     def read_data (filename)
#                             ^
# SyntaxError: invalid syntax

# %%
newdf = data52019[(data52019.chl_ctd)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-40edb8429d41> in <module>
# ----> 1 newdf = data52019[(data52019.chl_ctd)]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ...

# %%
data82018 = pd.read_csv ('2018-08.csv')

# %%
edata82018 = pd.read_csv ('ENutrients_2018-08.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-7-995cec868293> in <module>
# ----> 1 edata82018 = pd.read_csv ('ENutrients_2018-08.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
df = pd.read_csv("ENutrients_2018-08.csv", encoding="ISO-8859-1")

# %%
#this just worked, not super super sure why

# %%
df
# Out:
#     latitude  longitude     date  depth  Bottom Depth(m)  Sample Press(dBar)  \
# 0    41.3639   -71.4220  05:33.0    4.0             61.0                 2.0
# 1    41.1282   -71.0219  55:34.0    4.0             67.0                 2.0
# 2    40.9404   -70.7567  15:34.0    4.0             44.0                 3.0
# 3    40.8762   -70.3816  25:34.0    4.0             53.0                 3.0
# 4    40.4664   -69.9003  48:27.0    4.0             39.0                 3.0
# 5    40.8105   -69.1302  28:27.0    4.0             64.0                 3.0
# 6    40.6436   -68.3372  38:26.0    4.0             61.0                10.0
# 7    41.4818   -68.3369  28:27.0    4.0             67.0                10.0
# 8    41.4534   -67.8178  07:32.0    4.0             39.0                10.0
# 9    40.7645   -67.5984  27:31.0    4.0             64.0                10.0
# 10   40.0251   -69.2298  10:50.0    4.0             53.0                12.0
# ...

# %%
#format test 1

# %%
df = pd.read_csv("ENutrients_2018-08.csv", parse_dates=["date"], encoding="ISO-8859-1")
df
# Out:
#     latitude  longitude     date  depth  Bottom Depth(m)  Sample Press(dBar)  \
# 0    41.3639   -71.4220  05:33.0    4.0             61.0                 2.0
# 1    41.1282   -71.0219  55:34.0    4.0             67.0                 2.0
# 2    40.9404   -70.7567  15:34.0    4.0             44.0                 3.0
# 3    40.8762   -70.3816  25:34.0    4.0             53.0                 3.0
# 4    40.4664   -69.9003  48:27.0    4.0             39.0                 3.0
# 5    40.8105   -69.1302  28:27.0    4.0             64.0                 3.0
# 6    40.6436   -68.3372  38:26.0    4.0             61.0                10.0
# 7    41.4818   -68.3369  28:27.0    4.0             67.0                10.0
# 8    41.4534   -67.8178  07:32.0    4.0             39.0                10.0
# 9    40.7645   -67.5984  27:31.0    4.0             64.0                10.0
# 10   40.0251   -69.2298  10:50.0    4.0             53.0                12.0
# ...

# %%
Zeronan_df = df.fillna(0)
Zeronan_df
# Out:
#     latitude  longitude     date  depth  Bottom Depth(m)  Sample Press(dBar)  \
# 0    41.3639   -71.4220  05:33.0    4.0             61.0                 2.0
# 1    41.1282   -71.0219  55:34.0    4.0             67.0                 2.0
# 2    40.9404   -70.7567  15:34.0    4.0             44.0                 3.0
# 3    40.8762   -70.3816  25:34.0    4.0             53.0                 3.0
# 4    40.4664   -69.9003  48:27.0    4.0             39.0                 3.0
# 5    40.8105   -69.1302  28:27.0    4.0             64.0                 3.0
# 6    40.6436   -68.3372  38:26.0    4.0             61.0                10.0
# 7    41.4818   -68.3369  28:27.0    4.0             67.0                10.0
# 8    41.4534   -67.8178  07:32.0    4.0             39.0                10.0
# 9    40.7645   -67.5984  27:31.0    4.0             64.0                10.0
# 10   40.0251   -69.2298  10:50.0    4.0             53.0                12.0
# ...

# %%
#putting that little zero in parentheses alters any nan value to be zero

# %%
#for more detail tho

# %%
New_df = df.fillna({
    'temperature': -99999,
    "Sigma-t":-99999,
    "Oxygen(mg/L)": "No recording"
})
New_df
# Out:
#     latitude  longitude     date  depth  Bottom Depth(m)  Sample Press(dBar)  \
# 0    41.3639   -71.4220  05:33.0    4.0             61.0                 2.0
# 1    41.1282   -71.0219  55:34.0    4.0             67.0                 2.0
# 2    40.9404   -70.7567  15:34.0    4.0             44.0                 3.0
# 3    40.8762   -70.3816  25:34.0    4.0             53.0                 3.0
# 4    40.4664   -69.9003  48:27.0    4.0             39.0                 3.0
# 5    40.8105   -69.1302  28:27.0    4.0             64.0                 3.0
# 6    40.6436   -68.3372  38:26.0    4.0             61.0                10.0
# 7    41.4818   -68.3369  28:27.0    4.0             67.0                10.0
# 8    41.4534   -67.8178  07:32.0    4.0             39.0                10.0
# 9    40.7645   -67.5984  27:31.0    4.0             64.0                10.0
# 10   40.0251   -69.2298  10:50.0    4.0             53.0                12.0
# ...

# %%
New_df['NonNeg_Chlorophyll Fluorescence(µg/L)'] = New_df['Chlorophyll Fluorescence(µg/L)']

# %%
New_df
# Out:
#     latitude  longitude     date  depth  Bottom Depth(m)  Sample Press(dBar)  \
# 0    41.3639   -71.4220  05:33.0    4.0             61.0                 2.0
# 1    41.1282   -71.0219  55:34.0    4.0             67.0                 2.0
# 2    40.9404   -70.7567  15:34.0    4.0             44.0                 3.0
# 3    40.8762   -70.3816  25:34.0    4.0             53.0                 3.0
# 4    40.4664   -69.9003  48:27.0    4.0             39.0                 3.0
# 5    40.8105   -69.1302  28:27.0    4.0             64.0                 3.0
# 6    40.6436   -68.3372  38:26.0    4.0             61.0                10.0
# 7    41.4818   -68.3369  28:27.0    4.0             67.0                10.0
# 8    41.4534   -67.8178  07:32.0    4.0             39.0                10.0
# 9    40.7645   -67.5984  27:31.0    4.0             64.0                10.0
# 10   40.0251   -69.2298  10:50.0    4.0             53.0                12.0
# ...

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a861a8b3f1a> in <module>
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
df2
