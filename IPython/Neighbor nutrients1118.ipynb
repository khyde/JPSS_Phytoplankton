# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
import numpy as np
import seaborn as sns

# %%
stations1118 = pd.read_csv ('ECOMON stations 2018-11.csv')

# %%
loop1118 = stations1118.set_index('discrete_station_id', drop=False)

# %%
#f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
#ax1.plot(x, y)
#ax1.set_title('Sharing Y axis')
#ax2.scatter(x, y)

# %%
depth818 = stations818["depth"]
temp818 = stations818["temperature"]
sal818 = stations818["salinity"]
si818 = stations818["si_oh4"]
nit818 = stations818["no2_no3"]
chl818 = stations818["chl_a"]
totchl818 = stations818["tot_chl_a"]

depth1118 = stations1118["depth"]
temp1118 = stations1118["temperature"]
sal1118 = stations1118["salinity"]
si1118 = stations1118["si_oh4"]
nit1118 = stations1118["no2_no3"]
chl1118 = stations1118["chl_a"]
totchl1118 = stations1118["tot_chl_a"]

# %%
#nit = nitrite/nitrate
#fl = () fl818 = stations818[""]

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharey=True, figsize=(25,25))
ax1.set_title('August 2018 Depth Series', fontsize = '20')
ax1.plot(temp818, depth818, color='r')
ax1.plot(sal818, depth818, color ='b')
ax1.legend (["Temperature (°C)", "Salinity (PSU)"], shadow=True, fontsize = '16', loc = 'best')
ax1.tick_params(axis='both', labelsize=17)
ax1.grid ()
ax2.plot(chl818, depth818, 'g')
ax2.plot(totchl818, depth818, '-g')
ax2.legend (["Chlorophyll (uG/L)", "Total Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax2.tick_params(axis='both', labelsize=17)
ax2.grid ()
ax3.plot(nit818, depth818,'m')
ax3.plot(si818, depth818,'c')
ax3.legend (["Nitrite/Nitrate", "Silicate"], shadow=True, fontsize = '16', loc = 'best')
ax3.tick_params(axis='both', labelsize=17)
ax3.grid ()
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(sal818, depth818)
ax1.set_title('Sharing Y axis')
ax2.scatter(temp818, depth818)
plt.gca ().invert_yaxis ()

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharey=True, figsize=(25,25))
ax1.set_title('August 2018 Depth Series', fontsize = '20')
ax1.plot(temp818, depth818, color='r')
ax1.plot(sal818, depth818, color ='b')
ax1.legend (["Temperature (°C)", "Salinity (PSU)"], shadow=True, fontsize = '16', loc = 'best')
ax1.tick_params(axis='both', labelsize=17)
ax1.grid ()
ax2.plot(chl818, depth818, 'g')
ax2.plot(totchl818, depth818, '-g')
ax2.legend (["Chlorophyll (uG/L)", "Total Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax2.tick_params(axis='both', labelsize=17)
ax2.grid ()
ax3.plot(nit818, depth818,'m')
ax3.plot(si818, depth818,'c')
ax3.legend (["Nitrite/Nitrate", "Silicate"], shadow=True, fontsize = '16', loc = 'best')
ax3.tick_params(axis='both', labelsize=17)
ax3.grid ()
plt.gca ().invert_yaxis ()

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6 ) = plt.subplots(6, sharey=True, figsize=(25,25))
ax1.set_title('August 2018 Depth Series', fontsize = '20')
ax1.plot(temp818, depth818, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, fontsize = '16', loc = 'best')
ax1.tick_params(axis='x', labelsize=17)
ax1.grid ()
ax2.plot(sal818, depth818, color ='b')
ax2.legend (["Salinity (PSU)"], shadow=True, fontsize = '16', loc = 'best')
ax2.tick_params(axis='x', labelsize=17)
ax2.grid ()
ax3.plot(chl818, depth818, 'g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax3.tick_params(axis='x', labelsize=17)
ax3.grid ()
ax4.plot(totchl818, depth818, '-g')
ax4.legend (["Total Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax4.tick_params(axis='x', labelsize=17)
ax4.grid ()
ax5.plot(nit818, depth818,'m')
ax5.legend (["Nitrite/Nitrate"], shadow=True, fontsize = '16', loc = 'best')
ax5.tick_params(axis='x', labelsize=17)
ax5.grid ()
ax6.plot(si818, depth818,'c')
ax1.legend ([ "Silicate"], shadow=True, fontsize = '16', loc = 'best')
ax1.tick_params(axis='x', labelsize=17)
ax1.grid ()
plt.gca ().invert_yaxis ()

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6 ) = plt.subplots(6, sharey=True, figsize=(25,25))
ax1.set_title('August 2018 Depth Series', fontsize = '20')
ax1.plot(temp818, depth818, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, fontsize = '16', loc = 'best')
ax1.tick_params(axis='y', labelsize=17)
ax1.grid ()
ax2.plot(sal818, depth818, color ='b')
ax2.legend (["Salinity (PSU)"], shadow=True, fontsize = '16', loc = 'best')
ax2.tick_params(axis='y', labelsize=17)
ax2.grid ()
ax3.plot(chl818, depth818, 'g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax3.tick_params(axis='y', labelsize=17)
ax3.grid ()
ax4.plot(totchl818, depth818, '-g')
ax4.legend (["Total Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax4.tick_params(axis='y', labelsize=17)
ax4.grid ()
ax5.plot(nit818, depth818,'m')
ax5.legend (["Nitrite/Nitrate"], shadow=True, fontsize = '16', loc = 'best')
ax5.tick_params(axis='y', labelsize=17)
ax5.grid ()
ax6.plot(si818, depth818,'c')
ax1.legend ([ "Silicate"], shadow=True, fontsize = '16', loc = 'best')
ax1.tick_params(axis='y', labelsize=17)
ax1.grid ()
plt.gca ().invert_yaxis ()

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6 ) = plt.subplots(6, sharey='all', figsize=(25,25))
ax1.set_title('August 2018 Depth Series', fontsize = '20')
ax1.plot(temp818, depth818, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, fontsize = '16', loc = 'best')
ax1.tick_params(labelsize=17)
ax1.grid ()
ax2.plot(sal818, depth818, color ='b')
ax2.legend (["Salinity (PSU)"], shadow=True, fontsize = '16', loc = 'best')
ax2.tick_params(labelsize=17)
ax2.grid ()
ax3.plot(chl818, depth818, '.g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax3.tick_params(labelsize=17)
ax3.grid ()
ax4.plot(totchl818, depth818, '.g')
ax4.legend (["Total Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax4.tick_params(labelsize=17)
ax4.grid ()
ax5.plot(nit818, depth818,'.m')
ax5.legend (["Nitrite/Nitrate"], shadow=True, fontsize = '16', loc = 'best')
ax5.tick_params(labelsize=17)
ax5.grid ()
ax6.plot(si818, depth818,'.c')
ax6.legend ([ "Silicate"], shadow=True, fontsize = '16', loc = 'best')
ax6.tick_params(labelsize=17)
ax6.grid ()
plt.gca ().invert_yaxis ()

# %%
#ax.xaxis.tick_top() stck sol

# %%
f, (ax1, ax2, ax3, ax4 ) = plt.subplots(4, sharey=True, figsize=(25,25))
ax1.set_title('August 2018 Depth Series', fontsize = '20')
ax1.plot(chl818, depth818, 'g')
ax1.legend (["Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax1.tick_params(labelsize=17)
ax1.grid ()
ax2.plot(totchl818, depth818, '-g')
ax2.legend (["Total Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax2.tick_params(labelsize=17)
ax2.grid ()
ax3.plot(nit818, depth818,'m')
ax3.legend (["Nitrite/Nitrate"], shadow=True, fontsize = '16', loc = 'best')
ax3.tick_params(labelsize=17)
ax3.grid ()
ax4.plot(si818, depth818,'c')
ax4.legend ([ "Silicate"], shadow=True, fontsize = '16', loc = 'best')
ax4.tick_params(labelsize=17)
ax4.grid ()
plt.gca ().xaxis.tick_top()
plt.gca ().invert_yaxis ()

# %%
#f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 2, sharey=True)
#ax1.plot(sal818, depth818)
#ax1.set_title('Sharing Y axis')
#ax2.scatter(temp818, depth818)
#plt.gca ().invert_yaxis ()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(25,25))
ax1.plot(chl818, depth818, 'g')
ax1.plot(totchl818, depth818, '-g')
ax1.legend (["Chlorophyll (uG/L)", "Total Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax1.tick_params(axis='both', labelsize=17)
ax1.grid ()
ax2.plot(nit818, depth818,'m')
ax2.plot(si818, depth818,'c')
ax2.legend (["Nitrite/Nitrate", "Silicate"], shadow=True, fontsize = '16', loc = 'best')
ax2.tick_params(axis='both', labelsize=17)
ax2.grid ()
plt.gca ().xaxis.tick_top()
plt.gca ().invert_yaxis ()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(25,25))
ax1.plot(chl818, depth818, '.g')
ax1.plot(totchl818, depth818, '.g')
ax1.legend (["Chlorophyll (uG/L)", "Total Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax1.tick_params(axis='both', labelsize=17)
ax1.grid ()
ax2.plot(nit818, depth818,'.m')
ax2.plot(si818, depth818,'.c')
ax2.legend (["Nitrite/Nitrate", "Silicate"], shadow=True, fontsize = '16', loc = 'best')
ax2.tick_params(axis='both', labelsize=17)
ax2.grid ()
ax1.xaxis.tick_top()
ax2.xaxis.tick_top()
plt.gca ().invert_yaxis ()

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6 ) = plt.subplots(6, sharey='all', figsize=(25,25))
ax1.set_title('August 2018 Depth Series', fontsize = '20')
ax1.plot(temp818, depth818, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, fontsize = '16', loc = 'best')
ax1.tick_params(labelsize=17)
ax1.grid ()
ax2.plot(sal818, depth818, color ='b')
ax2.legend (["Salinity (PSU)"], shadow=True, fontsize = '16', loc = 'best')
ax2.tick_params(labelsize=17)
ax2.grid ()
ax3.plot(chl818, depth818, '.g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax3.tick_params(labelsize=17)
ax3.grid ()
ax4.plot(totchl818, depth818, '.g')
ax4.legend (["Total Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax4.tick_params(labelsize=17)
ax4.grid ()
ax5.plot(nit818, depth818,'.m')
ax5.legend (["Nitrite/Nitrate"], shadow=True, fontsize = '16', loc = 'best')
ax5.tick_params(labelsize=17)
ax5.grid ()
ax6.plot(si818, depth818,'.c')
ax6.legend ([ "Silicate"], shadow=True, fontsize = '16', loc = 'best')
ax6.tick_params(labelsize=17)
ax6.grid ()
plt.gca ().invert_yaxis ()

# %%
data = [[depth818], [chl818], [totchl818], [nit818], [si818]]
f, axs = plt.subplots(4,1,figsize=(15,15))
# 2x2, first axis
plt.subplot(121)
plt.scatter(chl818, depth818, color = 'g')
plt.scatter(totchl818, depth818, color = 'g')
plt.xlabel("Reg Chlorophyll (uG/L)","Tot Chlorophyll (uG/L)")
plt.grid ()
# 2x2, second axis
plt.subplot(122)
plt.scatter(nit818, depth818, color = 'm')
plt.scatter(si818, depth818, color = 'c')
plt.xlabel ("Nitrite/Nitrate","Silicate")
plt.grid ()
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-f83272b5fde3> in <module>
#       5 plt.scatter(chl818, depth818, color = 'g')
#       6 plt.scatter(totchl818, depth818, color = 'g')
# ----> 7 plt.xlabel("Reg Chlorophyll (uG/L)","Tot Chlorophyll (uG/L)")
#       8 plt.grid ()
#       9 # 2x2, second axis
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in xlabel(xlabel, fontdict, labelpad, **kwargs)
#    3068 def xlabel(xlabel, fontdict=None, labelpad=None, **kwargs):
#    3069     return gca().set_xlabel(
# -> 3070         xlabel, fontdict=fontdict, labelpad=labelpad, **kwargs)
#    3071
#    3072
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, **kwargs)
#     245         if labelpad is not None:
#     246             self.xaxis.labelpad = labelpad
# --> 247         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#     248
#     249     def get_ylabel(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in set_label_text(self, label, fontdict, **kwargs)
#    1596         self.label.set_text(label)
#    1597         if fontdict is not None:
# -> 1598             self.label.update(fontdict)
#    1599         self.label.update(kwargs)
#    1600         self.stale = True
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in update(self, kwargs)
#     174         # Update bbox last, as it depends on font properties.
#     175         sentinel = object()  # bbox can be None, so use another sentinel.
# --> 176         bbox = kwargs.pop("bbox", sentinel)
#     177         super().update(kwargs)
#     178         if bbox is not sentinel:
#
# AttributeError: 'str' object has no attribute 'pop'

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(25,25))
ax1.plot(chl818, depth818, 'xg')
ax1.plot(totchl818, depth818, 'xg')
ax1.legend (["Chlorophyll (uG/L)", "Total Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax1.tick_params(axis='both', labelsize=17)
ax1.grid ()
ax2.plot(nit818, depth818,'xm')
ax2.plot(si818, depth818,'xc')
ax2.legend (["Nitrite/Nitrate", "Silicate"], shadow=True, fontsize = '16', loc = 'best')
ax2.tick_params(axis='both', labelsize=17)
ax2.grid ()
ax1.xaxis.tick_top()
ax2.xaxis.tick_top()
plt.gca ().invert_yaxis ()

# %%
data = [[depth818], [chl818], [totchl818], [nit818], [si818]]
f, axs = plt.subplots(4,1, sharey =True, figsize=(15,15))
# first axis
plt.subplot(121)
plt.scatter(chl818, depth818, color = 'g')
plt.scatter(totchl818, depth818, color = 'g')
plt.legend (["Reg Chlorophyll (uG/L)", "Tot Chlorophyll (uG/L)"], shadow=True)
plt.gca ().invert_yaxis ()
plt.grid ()
# second axis
plt.subplot(122)
plt.scatter(nit818, depth818, color = 'm')
plt.scatter(si818, depth818, color = 'c')
plt.legend (["Nitrite/Nitrate (uG/L)", "Silicate (uG/L)"], shadow=True)
plt.gca ().invert_yaxis ()
plt.grid ()
plt.show()
plt.close()

# %%
# plt.xaxis.tick_top()

# %%
#set the index to 'discrete_station_id' then create dataframes for select stations i.e. station1 = df['664':'665'] which would then include all dta for a given station!!!

# %%
#df.set_index('month') stack

# %%
loop818 = stations818.set_index('discrete_station_id', drop=False)
loop1118 = stations1118.set_index('discrete_station_id', drop=False)

# %%
station1818 = loop818['129':'133']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-f7e001db5f4f> in <module>
# ----> 1 station1818 = loop818['129':'133']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2777
#    2778         # Do we have a slicer (on rows)?
# -> 2779         indexer = convert_to_index_sliceable(self, key)
#    2780         if indexer is not None:
#    2781             # either we have a slice or we have a string that can be converted
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2264     idx = obj.index
#    2265     if isinstance(key, slice):
# -> 2266         return idx._convert_slice_indexer(key, kind="getitem")
#    2267
#    2268     elif isinstance(key, str):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _convert_slice_indexer(self, key, kind)
#    2936             if self.is_integer() or is_index_slice:
#    2937                 return slice(
# -> 2938                     self._validate_indexer("slice", key.start, kind),
#    2939                     self._validate_indexer("slice", key.stop, kind),
#    2940                     self._validate_indexer("slice", key.step, kind),
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_indexer(self, form, key, kind)
#    4748             pass
#    4749         elif kind in ["iloc", "getitem"]:
# -> 4750             self._invalid_indexer(form, key)
#    4751         return key
#    4752
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    3075         """
#    3076         raise TypeError(
# -> 3077             f"cannot do {form} indexing on {type(self)} with these "
#    3078             f"indexers [{key}] of {type(key)}"
#    3079         )
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.numeric.Int64Index'> with these indexers [129] of <class 'str'>

# %%
stations818['129':'133']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-29ad5dbdfd82> in <module>
# ----> 1 stations818['129':'133']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2777
#    2778         # Do we have a slicer (on rows)?
# -> 2779         indexer = convert_to_index_sliceable(self, key)
#    2780         if indexer is not None:
#    2781             # either we have a slice or we have a string that can be converted
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2264     idx = obj.index
#    2265     if isinstance(key, slice):
# -> 2266         return idx._convert_slice_indexer(key, kind="getitem")
#    2267
#    2268     elif isinstance(key, str):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _convert_slice_indexer(self, key, kind)
#    2936             if self.is_integer() or is_index_slice:
#    2937                 return slice(
# -> 2938                     self._validate_indexer("slice", key.start, kind),
#    2939                     self._validate_indexer("slice", key.stop, kind),
#    2940                     self._validate_indexer("slice", key.step, kind),
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_indexer(self, form, key, kind)
#    4748             pass
#    4749         elif kind in ["iloc", "getitem"]:
# -> 4750             self._invalid_indexer(form, key)
#    4751         return key
#    4752
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    3075         """
#    3076         raise TypeError(
# -> 3077             f"cannot do {form} indexing on {type(self)} with these "
#    3078             f"indexers [{key}] of {type(key)}"
#    3079         )
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.range.RangeIndex'> with these indexers [129] of <class 'str'>

# %%
loop818['129':'133']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-916393c4919e> in <module>
# ----> 1 loop818['129':'133']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2777
#    2778         # Do we have a slicer (on rows)?
# -> 2779         indexer = convert_to_index_sliceable(self, key)
#    2780         if indexer is not None:
#    2781             # either we have a slice or we have a string that can be converted
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2264     idx = obj.index
#    2265     if isinstance(key, slice):
# -> 2266         return idx._convert_slice_indexer(key, kind="getitem")
#    2267
#    2268     elif isinstance(key, str):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _convert_slice_indexer(self, key, kind)
#    2936             if self.is_integer() or is_index_slice:
#    2937                 return slice(
# -> 2938                     self._validate_indexer("slice", key.start, kind),
#    2939                     self._validate_indexer("slice", key.stop, kind),
#    2940                     self._validate_indexer("slice", key.step, kind),
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_indexer(self, form, key, kind)
#    4748             pass
#    4749         elif kind in ["iloc", "getitem"]:
# -> 4750             self._invalid_indexer(form, key)
#    4751         return key
#    4752
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    3075         """
#    3076         raise TypeError(
# -> 3077             f"cannot do {form} indexing on {type(self)} with these "
#    3078             f"indexers [{key}] of {type(key)}"
#    3079         )
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.numeric.Int64Index'> with these indexers [129] of <class 'str'>

# %%
data = [[depth818], [chl818], [totchl818], [nit818], [si818]]
f, axs = plt.subplots(4,1, sharey =True, figsize=(15,15))
# first axis
plt.subplot(141)
plt.scatter(chl818, depth818, color = 'g')
plt.scatter(totchl818, depth818, color = 'g')
plt.legend (["Reg Chlorophyll (uG/L)", "Tot Chlorophyll (uG/L)"], shadow=True)
plt.gca ().invert_yaxis ()
plt.grid ()
# second axis
plt.subplot(142)
plt.scatter(nit818, depth818, color = 'm')
plt.scatter(si818, depth818, color = 'c')
plt.legend (["Nitrite/Nitrate (uG/L)", "Silicate (uG/L)"], shadow=True)
plt.gca ().invert_yaxis ()
plt.grid ()
plt.show()
plt.close()

# %%
# the fix for making 4 instead of just 2 vertically came from the first "2" in 122 and 121, changing this to 4 allowed for the plotting of a 143 and a 144

# %%
# Limit to 50 so that the chlorophyll still shows decently

# %%
#see if you can make 'em stockier (shorter and thicker)

# %%
data = [[depth818], [chl818], [totchl818], [nit818], [si818]]
f, axs = plt.subplots(4,1, sharey =True, figsize=(15,10))
# first axis
plt.subplot(131)
plt.plot(chl818, depth818, '.g')
plt.plot(totchl818, depth818, '.g')
plt.legend (["Reg Chlorophyll (uG/L)", "Tot Chlorophyll (uG/L)"], shadow=True)
plt.gca ().invert_yaxis ()
plt.grid ()
# second axis
plt.subplot(132)
plt.plot(nit818, depth818, '.m')
plt.plot(si818, depth818,  '.c')
plt.ylim (0,50)
plt.legend (["Nitrite/Nitrate (uG/L)", "Silicate (uG/L)"], shadow=True)
plt.gca ().invert_yaxis ()
plt.grid ()
plt.show()
plt.close()

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6 ) = plt.subplots(6, sharey='all', figsize=(25,25))
ax1.set_title('August 2018 Depth Series', fontsize = '20')
ax1.plot(temp818, depth818, color='r')
ax1.legend (["Temperature (°C)"], shadow=True, fontsize = '16', loc = 'best')
ax1.tick_params(labelsize=17)
ax1.grid ()
ax2.plot(sal818, depth818, color ='b')
ax2.legend (["Salinity (PSU)"], shadow=True, fontsize = '16', loc = 'best')
ax2.tick_params(labelsize=17)
ax2.grid ()
ax3.plot(chl818, depth818, '.g')
ax3.legend (["Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax3.tick_params(labelsize=17)
ax3.grid ()
ax4.plot(totchl818, depth818, '.g')
ax4.legend (["Total Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
ax4.tick_params(labelsize=17)
ax4.grid ()
ax5.plot(nit818, depth818,'.m')
ax5.legend (["Nitrite/Nitrate"], shadow=True, fontsize = '16', loc = 'best')
ax5.tick_params(labelsize=17)
ax5.grid ()
ax6.plot(si818, depth818,'.c')
ax6.legend ([ "Silicate"], shadow=True, fontsize = '16', loc = 'best')
ax6.tick_params(labelsize=17)
ax6.grid ()
plt.gca ().invert_yaxis ()

# %%
data = [[depth818], [temp818], [sal818], [chl818], [totchl818], [nit818], [si818]]
f, axs = plt.subplots(4,1, sharey ='all', figsize=(15,10))
#plot 1
plt.subplot(131)
plt.plot(temp818, depth818, color='r')
plt.legend (["Temperature (°C)"], shadow=True, fontsize = '16', loc = 'best')
plt.tick_params(labelsize=17)
plt.grid ()
plt.plot(sal818, depth818, color ='b')
plt.legend (["Salinity (PSU)"], shadow=True, fontsize = '16', loc = 'best')
plt.tick_params(labelsize=17)
plt.grid ()
#plot 2
plt.subplot(132)
plt.plot(chl818, depth818, '.g')
plt.legend (["Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
plt.tick_params(labelsize=17)
plt.grid ()
plt.plot(totchl818, depth818, '.g')
plt.legend (["Total Chlorophyll (uG/L)"], shadow=True, fontsize = '16', loc = 'best')
plt.tick_params(labelsize=17)
plt.grid ()
#plot 3
plt.subplot(133)
plt.plot(nit818, depth818,'.m')
plt.legend (["Nitrite/Nitrate"], shadow=True, fontsize = '16', loc = 'best')
plt.tick_params(labelsize=17)
plt.grid ()
plt.plot(si818, depth818,'.c')
plt.legend ([ "Silicate"], shadow=True, fontsize = '16', loc = 'best')
plt.tick_params(labelsize=17)
plt.grid ()
plt.show ()
plt.close ()

# %%
data1 = [[depth818], [temp818], [sal818], [chl818], [totchl818], [nit818], [si818]]
f, axs = plt.subplots(4,1, sharey ='all', figsize=(15,10))
#plot 1
plt.subplot(131)
plt.plot(temp818, depth818, '.r')
plt.plot(sal818, depth818, '.b')
plt.ylim (0,50)
plt.legend (["Temperature (°C)", "Salinity (PSU)"], shadow=True, fontsize = '10', loc = 'best')
plt.tick_params(labelsize=17)
plt.gca ().invert_yaxis ()
plt.grid ()
#plot 2
plt.subplot(132)
plt.plot(chl818, depth818, '.g')
plt.plot(totchl818, depth818, '.g')
plt.ylim (0,50)
plt.legend (["Chlorophyll (uG/L)", "Total Chlorophyll (uG/L)"], shadow=True, fontsize = '10', loc = 'best')
plt.tick_params(labelsize=17)
plt.gca ().invert_yaxis ()
plt.grid ()
#plot 3
plt.subplot(133)
plt.plot(nit818, depth818,'.m')
plt.plot(si818, depth818,'.c')
plt.ylim (0,50)
plt.legend (["Nitrite/Nitrate", "Silicate"], shadow=True, fontsize = '10', loc = 'best')
plt.tick_params(labelsize=17)
plt.gca ().invert_yaxis ()
plt.grid ()
plt.show ()
plt.close ()

# %%
for i in 'discrete_station_id'
# Out:
#   File "<ipython-input-43-98f340ad29d8>", line 1
#     for i in 'discrete_station_id'
#                                   ^
# SyntaxError: invalid syntax

# %%
loop818
# Out:
#                      discrete_station_id  latitude  longitude     date  depth  \
# discrete_station_id
# 163                                  163   38.0067   -74.9583  00:00.0    1.5
# 163                                  163   38.0067   -74.9583  00:00.0    2.5
# 163                                  163   38.0067   -74.9583  00:00.0    3.5
# 163                                  163   38.0067   -74.9583  00:00.0    4.5
# 163                                  163   38.0067   -74.9583  00:00.0    5.5
# ...                                  ...       ...        ...      ...    ...
# 192                                  192   41.0982   -70.6263  07:00.0   36.5
# 192                                  192   41.0982   -70.6263  07:00.0   37.5
# 192                                  192   41.0982   -70.6263  07:00.0   38.5
# 192                                  192   41.0982   -70.6263  07:00.0   39.5
# 192                                  192   41.0982   -70.6263  07:00.0   40.5
#
#                      temperature  salinity  chl_ctd  pc_ctd  cdom_ctd  ...  \
# discrete_station_id                                                    ...
# 163                        17.28    31.799     0.68     NaN       NaN  ...
# 163                        17.28    31.799     0.71     NaN       NaN  ...
# 163                        17.27    31.799     0.69     NaN       NaN  ...
# 163                        17.28    31.799     0.72     NaN       NaN  ...
# 163                        17.28    31.799     0.73     NaN       NaN  ...
# ...                          ...       ...      ...     ...       ...  ...
# 192                        13.49    32.391     1.79     NaN       NaN  ...
# 192                        13.49    32.392     2.39     NaN       NaN  ...
# 192                        13.49    32.392     1.92     NaN       NaN  ...
# 192                        13.49    32.391     1.54     NaN       NaN  ...
# 192                        13.49    32.392     2.06     NaN       NaN  ...
#
#                      ppc_tcar  ppc_tcar_sd  tchl_tcar  tchl_tcar_sd  ppc_tpg  \
# discrete_station_id
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                      0.25          NaN       3.11           NaN     0.06
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# ...                       ...          ...        ...           ...      ...
# 192                       NaN          NaN        NaN           NaN      NaN
# 192                       NaN          NaN        NaN           NaN      NaN
# 192                       NaN          NaN        NaN           NaN      NaN
# 192                       NaN          NaN        NaN           NaN      NaN
# 192                       NaN          NaN        NaN           NaN      NaN
#
#                      ppc_tpg_sd  psp_tpg  psp_tpg_sd  tchla_tpg  tchla_tpg_sd
# discrete_station_id
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN     0.94         NaN       0.64           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# ...                         ...      ...         ...        ...           ...
# 192                         NaN      NaN         NaN        NaN           NaN
# 192                         NaN      NaN         NaN        NaN           NaN
# 192                         NaN      NaN         NaN        NaN           NaN
# 192                         NaN      NaN         NaN        NaN           NaN
# 192                         NaN      NaN         NaN        NaN           NaN
#
# [1451 rows x 104 columns]

# %%
stations818
# Out:
#       discrete_station_id  latitude  longitude                   date  depth  \
# 0                     129   41.1044   -70.6203  2018-08-23 12:45:00.0    2.5
# 1                     129   41.1044   -70.6203  2018-08-23 12:45:00.0    3.5
# 2                     129   41.1044   -70.6203  2018-08-23 12:45:00.0    4.5
# 3                     129   41.1044   -70.6203  2018-08-23 12:45:00.0    5.5
# 4                     129   41.1044   -70.6203  2018-08-23 12:45:00.0    6.5
# ...                   ...       ...        ...                    ...    ...
# 2645                  159   37.7005   -74.2562  2018-08-29 23:42:00.0  105.5
# 2646                  159   37.7005   -74.2562  2018-08-29 23:42:00.0  106.5
# 2647                  159   37.7005   -74.2562  2018-08-29 23:42:00.0  107.5
# 2648                  159   37.7005   -74.2562  2018-08-29 23:42:00.0  108.5
# 2649                  159   37.7005   -74.2562  2018-08-29 23:42:00.0  109.5
#
#       temperature  salinity  chl_ctd  pc_ctd  cdom_ctd  ...  ppc_tcar_sd  \
# 0           18.34    32.263     1.54     NaN       NaN  ...          NaN
# 1           18.31    32.262     1.60     NaN       NaN  ...       0.0071
# 2           18.32    32.262     1.61     NaN       NaN  ...          NaN
# 3           18.29    32.261     1.64     NaN       NaN  ...          NaN
# 4           18.29    32.262     1.70     NaN       NaN  ...          NaN
# ...           ...       ...      ...     ...       ...  ...          ...
# 2645        12.68    35.443     0.29     NaN       NaN  ...          NaN
# 2646        12.70    35.462     0.31     NaN       NaN  ...          NaN
# 2647        12.72    35.481     0.30     NaN       NaN  ...          NaN
# 2648        12.73    35.494     0.28     NaN       NaN  ...          NaN
# 2649        12.72    35.501     0.30     NaN       NaN  ...          NaN
#
#       tchl_tcar  tchl_tcar_sd  ppc_tpg  ppc_tpg_sd  psp_tpg  psp_tpg_sd  \
# 0           NaN           NaN      NaN         NaN      NaN         NaN
# 1          2.85        0.1131     0.08         0.0     0.92         0.0
# 2           NaN           NaN      NaN         NaN      NaN         NaN
# 3           NaN           NaN      NaN         NaN      NaN         NaN
# 4           NaN           NaN      NaN         NaN      NaN         NaN
# ...         ...           ...      ...         ...      ...         ...
# 2645        NaN           NaN      NaN         NaN      NaN         NaN
# 2646        NaN           NaN      NaN         NaN      NaN         NaN
# 2647        NaN           NaN      NaN         NaN      NaN         NaN
# 2648        NaN           NaN      NaN         NaN      NaN         NaN
# 2649        NaN           NaN      NaN         NaN      NaN         NaN
#
#       tchla_tpg  tchla_tpg_sd  Unnamed: 104
# 0           NaN           NaN           NaN
# 1         0.605        0.0071           NaN
# 2           NaN           NaN           NaN
# 3           NaN           NaN           NaN
# 4           NaN           NaN           NaN
# ...         ...           ...           ...
# 2645        NaN           NaN           NaN
# 2646        NaN           NaN           NaN
# 2647        NaN           NaN           NaN
# 2648        NaN           NaN           NaN
# 2649        NaN           NaN           NaN
#
# [2650 rows x 105 columns]

# %%
loop818
# Out:
#                      discrete_station_id  latitude  longitude     date  depth  \
# discrete_station_id
# 163                                  163   38.0067   -74.9583  00:00.0    1.5
# 163                                  163   38.0067   -74.9583  00:00.0    2.5
# 163                                  163   38.0067   -74.9583  00:00.0    3.5
# 163                                  163   38.0067   -74.9583  00:00.0    4.5
# 163                                  163   38.0067   -74.9583  00:00.0    5.5
# ...                                  ...       ...        ...      ...    ...
# 192                                  192   41.0982   -70.6263  07:00.0   36.5
# 192                                  192   41.0982   -70.6263  07:00.0   37.5
# 192                                  192   41.0982   -70.6263  07:00.0   38.5
# 192                                  192   41.0982   -70.6263  07:00.0   39.5
# 192                                  192   41.0982   -70.6263  07:00.0   40.5
#
#                      temperature  salinity  chl_ctd  pc_ctd  cdom_ctd  ...  \
# discrete_station_id                                                    ...
# 163                        17.28    31.799     0.68     NaN       NaN  ...
# 163                        17.28    31.799     0.71     NaN       NaN  ...
# 163                        17.27    31.799     0.69     NaN       NaN  ...
# 163                        17.28    31.799     0.72     NaN       NaN  ...
# 163                        17.28    31.799     0.73     NaN       NaN  ...
# ...                          ...       ...      ...     ...       ...  ...
# 192                        13.49    32.391     1.79     NaN       NaN  ...
# 192                        13.49    32.392     2.39     NaN       NaN  ...
# 192                        13.49    32.392     1.92     NaN       NaN  ...
# 192                        13.49    32.391     1.54     NaN       NaN  ...
# 192                        13.49    32.392     2.06     NaN       NaN  ...
#
#                      ppc_tcar  ppc_tcar_sd  tchl_tcar  tchl_tcar_sd  ppc_tpg  \
# discrete_station_id
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                      0.25          NaN       3.11           NaN     0.06
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# ...                       ...          ...        ...           ...      ...
# 192                       NaN          NaN        NaN           NaN      NaN
# 192                       NaN          NaN        NaN           NaN      NaN
# 192                       NaN          NaN        NaN           NaN      NaN
# 192                       NaN          NaN        NaN           NaN      NaN
# 192                       NaN          NaN        NaN           NaN      NaN
#
#                      ppc_tpg_sd  psp_tpg  psp_tpg_sd  tchla_tpg  tchla_tpg_sd
# discrete_station_id
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN     0.94         NaN       0.64           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# ...                         ...      ...         ...        ...           ...
# 192                         NaN      NaN         NaN        NaN           NaN
# 192                         NaN      NaN         NaN        NaN           NaN
# 192                         NaN      NaN         NaN        NaN           NaN
# 192                         NaN      NaN         NaN        NaN           NaN
# 192                         NaN      NaN         NaN        NaN           NaN
#
# [1451 rows x 104 columns]

# %%
loop818.loc['163']
# Out:
#                      discrete_station_id  latitude  longitude     date  depth  \
# discrete_station_id
# 163                                  163   38.0067   -74.9583  00:00.0    1.5
# 163                                  163   38.0067   -74.9583  00:00.0    2.5
# 163                                  163   38.0067   -74.9583  00:00.0    3.5
# 163                                  163   38.0067   -74.9583  00:00.0    4.5
# 163                                  163   38.0067   -74.9583  00:00.0    5.5
# 163                                  163   38.0067   -74.9583  00:00.0    6.5
# 163                                  163   38.0067   -74.9583  00:00.0    7.5
# 163                                  163   38.0067   -74.9583  00:00.0    8.5
# 163                                  163   38.0067   -74.9583  00:00.0    9.5
# 163                                  163   38.0067   -74.9583  00:00.0   10.5
# 163                                  163   38.0067   -74.9583  00:00.0   11.5
# 163                                  163   38.0067   -74.9583  00:00.0   12.5
# 163                                  163   38.0067   -74.9583  00:00.0   13.5
# 163                                  163   38.0067   -74.9583  00:00.0   14.5
# 163                                  163   38.0067   -74.9583  00:00.0   15.5
# 163                                  163   38.0067   -74.9583  00:00.0   16.5
# 163                                  163   38.0067   -74.9583  00:00.0   17.5
# 163                                  163   38.0067   -74.9583  00:00.0   18.5
#
#                      temperature  salinity  chl_ctd  pc_ctd  cdom_ctd  ...  \
# discrete_station_id                                                    ...
# 163                        17.28    31.799     0.68     NaN       NaN  ...
# 163                        17.28    31.799     0.71     NaN       NaN  ...
# 163                        17.27    31.799     0.69     NaN       NaN  ...
# 163                        17.28    31.799     0.72     NaN       NaN  ...
# 163                        17.28    31.799     0.73     NaN       NaN  ...
# 163                        17.28    31.799     0.71     NaN       NaN  ...
# 163                        17.28    31.799     0.70     NaN       NaN  ...
# 163                        17.27    31.800     0.71     NaN       NaN  ...
# 163                        17.27    31.801     0.70     NaN       NaN  ...
# 163                        17.27    31.802     0.68     NaN       NaN  ...
# 163                        17.27    31.805     0.71     NaN       NaN  ...
# 163                        17.26    31.811     0.68     NaN       NaN  ...
# 163                        17.27    31.808     0.68     NaN       NaN  ...
# 163                        17.24    31.842     0.67     NaN       NaN  ...
# 163                        17.22    31.873     0.61     NaN       NaN  ...
# 163                        17.21    31.902     0.57     NaN       NaN  ...
# 163                        17.20    31.908     0.59     NaN       NaN  ...
# 163                        17.20    31.910     0.64     NaN       NaN  ...
#
#                      ppc_tcar  ppc_tcar_sd  tchl_tcar  tchl_tcar_sd  ppc_tpg  \
# discrete_station_id
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                      0.25          NaN       3.11           NaN     0.06
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
# 163                       NaN          NaN        NaN           NaN      NaN
#
#                      ppc_tpg_sd  psp_tpg  psp_tpg_sd  tchla_tpg  tchla_tpg_sd
# discrete_station_id
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN     0.94         NaN       0.64           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
# 163                         NaN      NaN         NaN        NaN           NaN
#
# [18 rows x 104 columns]

# %%
for i in loop818.loc['163']
# Out:
#   File "<ipython-input-12-03f0d7d80b6c>", line 1
#     for i in loop818.loc['163']
#                                ^
# SyntaxError: invalid syntax

# %%
# groups in 818 are 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159

# %%
import numpy as np 
def createList(r1, r2): 
    return np.arange(r1, r2+1, 1) 
      
# Driver Code 
r1, r2 = 163, 192
print(createList(r1, r2))
# Out:
# [163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180
#  181 182 183 184 185 186 187 188 189 190 191 192]

# %%
#this was a lazy way of getting the numbers for the above note

# %%
g818 = 129, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159

# %%
g818
# Out:
# (129,
#  130,
#  131,
#  132,
#  133,
#  134,
#  135,
#  136,
#  137,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  144,
#  145,
#  146,
#  147,
#  148,
#  149,
#  150,
#  151,
#  152,
#  153,
#  154,
#  155,
#  156,
#  157,
#  158,
#  159)

# %%
loop818
# Out:
#                      discrete_station_id  latitude  longitude  \
# discrete_station_id
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# ...                                  ...       ...        ...
# 159                                  159   37.7005   -74.2562
# 159                                  159   37.7005   -74.2562
# 159                                  159   37.7005   -74.2562
# 159                                  159   37.7005   -74.2562
# 159                                  159   37.7005   -74.2562
#
#                                       date  depth  temperature  salinity  \
# discrete_station_id
# 129                  2018-08-23 12:45:00.0    2.5        18.34    32.263
# 129                  2018-08-23 12:45:00.0    3.5        18.31    32.262
# 129                  2018-08-23 12:45:00.0    4.5        18.32    32.262
# 129                  2018-08-23 12:45:00.0    5.5        18.29    32.261
# 129                  2018-08-23 12:45:00.0    6.5        18.29    32.262
# ...                                    ...    ...          ...       ...
# 159                  2018-08-29 23:42:00.0  105.5        12.68    35.443
# 159                  2018-08-29 23:42:00.0  106.5        12.70    35.462
# 159                  2018-08-29 23:42:00.0  107.5        12.72    35.481
# 159                  2018-08-29 23:42:00.0  108.5        12.73    35.494
# 159                  2018-08-29 23:42:00.0  109.5        12.72    35.501
#
#                      chl_ctd  pc_ctd  cdom_ctd  ...  ppc_tcar_sd  tchl_tcar  \
# discrete_station_id                             ...
# 129                     1.54     NaN       NaN  ...          NaN        NaN
# 129                     1.60     NaN       NaN  ...       0.0071       2.85
# 129                     1.61     NaN       NaN  ...          NaN        NaN
# 129                     1.64     NaN       NaN  ...          NaN        NaN
# 129                     1.70     NaN       NaN  ...          NaN        NaN
# ...                      ...     ...       ...  ...          ...        ...
# 159                     0.29     NaN       NaN  ...          NaN        NaN
# 159                     0.31     NaN       NaN  ...          NaN        NaN
# 159                     0.30     NaN       NaN  ...          NaN        NaN
# 159                     0.28     NaN       NaN  ...          NaN        NaN
# 159                     0.30     NaN       NaN  ...          NaN        NaN
#
#                      tchl_tcar_sd  ppc_tpg  ppc_tpg_sd  psp_tpg  psp_tpg_sd  \
# discrete_station_id
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                        0.1131     0.08         0.0     0.92         0.0
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# ...                           ...      ...         ...      ...         ...
# 159                           NaN      NaN         NaN      NaN         NaN
# 159                           NaN      NaN         NaN      NaN         NaN
# 159                           NaN      NaN         NaN      NaN         NaN
# 159                           NaN      NaN         NaN      NaN         NaN
# 159                           NaN      NaN         NaN      NaN         NaN
#
#                      tchla_tpg  tchla_tpg_sd  Unnamed: 104
# discrete_station_id
# 129                        NaN           NaN           NaN
# 129                      0.605        0.0071           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# ...                        ...           ...           ...
# 159                        NaN           NaN           NaN
# 159                        NaN           NaN           NaN
# 159                        NaN           NaN           NaN
# 159                        NaN           NaN           NaN
# 159                        NaN           NaN           NaN
#
# [2650 rows x 105 columns]

# %%
loop818.loc['129']
# Out:
#                      discrete_station_id  latitude  longitude  \
# discrete_station_id
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
# 129                                  129   41.1044   -70.6203
#
#                                       date  depth  temperature  salinity  \
# discrete_station_id
# 129                  2018-08-23 12:45:00.0    2.5        18.34    32.263
# 129                  2018-08-23 12:45:00.0    3.5        18.31    32.262
# 129                  2018-08-23 12:45:00.0    4.5        18.32    32.262
# 129                  2018-08-23 12:45:00.0    5.5        18.29    32.261
# 129                  2018-08-23 12:45:00.0    6.5        18.29    32.262
# 129                  2018-08-23 12:45:00.0    7.5        18.29    32.262
# 129                  2018-08-23 12:45:00.0    8.5        18.29    32.263
# 129                  2018-08-23 12:45:00.0    9.5        18.28    32.262
# 129                  2018-08-23 12:45:00.0   10.5        18.23    32.259
# 129                  2018-08-23 12:45:00.0   11.5        18.11    32.251
# 129                  2018-08-23 12:45:00.0   12.5        17.84    32.238
# 129                  2018-08-23 12:45:00.0   13.5        17.14    32.223
# 129                  2018-08-23 12:45:00.0   14.5        15.58    32.209
# 129                  2018-08-23 12:45:00.0   15.5        15.04    32.160
# 129                  2018-08-23 12:45:00.0   16.5        14.88    32.179
# 129                  2018-08-23 12:45:00.0   17.5        14.82    32.188
# 129                  2018-08-23 12:45:00.0   18.5        14.74    32.206
# 129                  2018-08-23 12:45:00.0   19.5        14.65    32.224
# 129                  2018-08-23 12:45:00.0   20.5        14.59    32.235
# 129                  2018-08-23 12:45:00.0   21.5        14.50    32.247
# 129                  2018-08-23 12:45:00.0   22.5        14.44    32.259
# 129                  2018-08-23 12:45:00.0   23.5        14.34    32.273
# 129                  2018-08-23 12:45:00.0   24.5        14.25    32.286
# 129                  2018-08-23 12:45:00.0   25.5        14.19    32.301
# 129                  2018-08-23 12:45:00.0   26.5        14.09    32.315
# 129                  2018-08-23 12:45:00.0   27.5        14.06    32.321
# 129                  2018-08-23 12:45:00.0   28.5        14.00    32.328
# 129                  2018-08-23 12:45:00.0   29.5        13.99    32.329
# 129                  2018-08-23 12:45:00.0   30.5        13.97    32.331
# 129                  2018-08-23 12:45:00.0   31.5        13.73    32.379
# 129                  2018-08-23 12:45:00.0   32.5        13.41    32.425
# 129                  2018-08-23 12:45:00.0   33.5        13.25    32.448
# 129                  2018-08-23 12:45:00.0   34.5        13.21    32.452
# 129                  2018-08-23 12:45:00.0   35.5        13.19    32.454
# 129                  2018-08-23 12:45:00.0   36.5        13.19    32.456
# 129                  2018-08-23 12:45:00.0   37.5        13.18    32.457
# 129                  2018-08-23 12:45:00.0   38.5        13.18    32.458
# 129                  2018-08-23 12:45:00.0   39.5        13.17    32.459
# 129                  2018-08-23 12:45:00.0   40.5        13.17    32.460
#
#                      chl_ctd  pc_ctd  cdom_ctd  ...  ppc_tcar_sd  tchl_tcar  \
# discrete_station_id                             ...
# 129                     1.54     NaN       NaN  ...          NaN        NaN
# 129                     1.60     NaN       NaN  ...       0.0071      2.850
# 129                     1.61     NaN       NaN  ...          NaN        NaN
# 129                     1.64     NaN       NaN  ...          NaN        NaN
# 129                     1.70     NaN       NaN  ...          NaN        NaN
# 129                     1.81     NaN       NaN  ...          NaN        NaN
# 129                     1.83     NaN       NaN  ...          NaN        NaN
# 129                     1.79     NaN       NaN  ...          NaN        NaN
# 129                     1.89     NaN       NaN  ...          NaN        NaN
# 129                     2.18     NaN       NaN  ...          NaN        NaN
# 129                     2.66     NaN       NaN  ...          NaN        NaN
# 129                     3.80     NaN       NaN  ...       0.0000      2.525
# 129                     4.09     NaN       NaN  ...          NaN        NaN
# 129                     4.01     NaN       NaN  ...          NaN        NaN
# 129                     3.71     NaN       NaN  ...          NaN        NaN
# 129                     3.56     NaN       NaN  ...          NaN        NaN
# 129                     3.62     NaN       NaN  ...          NaN        NaN
# 129                     3.34     NaN       NaN  ...          NaN        NaN
# 129                     3.35     NaN       NaN  ...          NaN        NaN
# 129                     3.58     NaN       NaN  ...          NaN        NaN
# 129                     3.69     NaN       NaN  ...          NaN        NaN
# 129                     3.87     NaN       NaN  ...          NaN        NaN
# 129                     4.47     NaN       NaN  ...          NaN        NaN
# 129                     4.37     NaN       NaN  ...          NaN        NaN
# 129                     3.37     NaN       NaN  ...          NaN        NaN
# 129                     3.88     NaN       NaN  ...          NaN        NaN
# 129                     4.19     NaN       NaN  ...          NaN        NaN
# 129                     3.20     NaN       NaN  ...          NaN        NaN
# 129                     3.72     NaN       NaN  ...          NaN        NaN
# 129                     2.90     NaN       NaN  ...          NaN        NaN
# 129                     2.19     NaN       NaN  ...          NaN        NaN
# 129                     1.86     NaN       NaN  ...          NaN        NaN
# 129                     1.78     NaN       NaN  ...          NaN        NaN
# 129                     1.62     NaN       NaN  ...          NaN        NaN
# 129                     1.73     NaN       NaN  ...          NaN        NaN
# 129                     1.58     NaN       NaN  ...          NaN        NaN
# 129                     1.69     NaN       NaN  ...          NaN        NaN
# 129                     1.41     NaN       NaN  ...          NaN        NaN
# 129                     1.56     NaN       NaN  ...          NaN        NaN
#
#                      tchl_tcar_sd  ppc_tpg  ppc_tpg_sd  psp_tpg  psp_tpg_sd  \
# discrete_station_id
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                        0.1131     0.08         0.0     0.92         0.0
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                        0.1202     0.06         0.0     0.94         0.0
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
# 129                           NaN      NaN         NaN      NaN         NaN
#
#                      tchla_tpg  tchla_tpg_sd  Unnamed: 104
# discrete_station_id
# 129                        NaN           NaN           NaN
# 129                      0.605        0.0071           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                      0.550        0.0141           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
# 129                        NaN           NaN           NaN
#
# [39 rows x 105 columns]

# %%
loop818.loc['129, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# KeyError: '129, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-0df83e67fd8f> in <module>
# ----> 1 loop818.loc['129, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1962         # fall thru to straight lookup
#    1963         self._validate_key(key, axis)
# -> 1964         return self._get_label(key, axis=axis)
#    1965
#    1966
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     622             raise IndexingError("no slices here, handle elsewhere")
#     623
# --> 624         return self.obj._xs(label, axis=axis)
#     625
#     626     def _get_loc(self, key: int, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# KeyError: '129, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159'

# %%
loop1118.loc[('169',"latitude")]
# Out:
# discrete_station_id
# 169    35.9983
# 169    35.9983
# 169    35.9983
# 169    35.9983
# 169    35.9983
#         ...
# 169    35.9983
# 169    35.9983
# 169    35.9983
# 169    35.9983
# 169    35.9983
# Name: latitude, Length: 374, dtype: float64

# %%
stations = [163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192]

# %%
for station in stations:
    try:
        loop1118.loc[station,"latitude"]
    except KeyError:
        print ("key does not exist "+str(station))
# Out:
# key does not exist 164
# key does not exist 165
# key does not exist 166
# key does not exist 167
# key does not exist 171
# key does not exist 172
# key does not exist 173
# key does not exist 176
# key does not exist 177
# key does not exist 181
# key does not exist 182
# key does not exist 184
# key does not exist 185
# key does not exist 186
# key does not exist 187
# key does not exist 188
# key does not exist 190
# key does not exist 191

# %%
#runs a detail of what stations need to be removed

# %%
for station in stations:
    try:
        data = loop818.loc[station,"temperature"]
        f, axs = plt.subplots(4,1, sharey ='all', figsize=(15,10))
        plt.title ("{}-{}to{}".format(station, station818["date"].min().date, station818["date"].max().date))
        #plot 1
        plt.subplot(131)
        plt.plot(loop818.loc[station,"temperature"], loop818.loc[station,"depth"], '.r')
        plt.plot(loop818.loc[station,"salinity"], loop818.loc[station,"depth"], '.b')
        plt.ylim (0,50)
        plt.legend (["Temperature (°C)", "Salinity (PSU)"], shadow=True, fontsize = '10', loc = 'best')
        plt.tick_params(labelsize=17)
        plt.gca ().invert_yaxis ()
        plt.grid ()
        #plot 2
        plt.subplot(132)
        plt.plot(loop818.loc[station,"chl_a"], loop818.loc[station,"depth"], '.g')
        plt.plot(loop818.loc[station,"tot_chl_a"], loop818.loc[station,"depth"], '.g')
        plt.ylim (0,50)
        plt.legend (["Chlorophyll (uG/L)", "Total Chlorophyll (uG/L)"], shadow=True, fontsize = '10', loc = 'best')
        plt.tick_params(labelsize=17)
        plt.gca ().invert_yaxis ()
        plt.grid ()
        #plot 3
        plt.subplot(133)
        plt.plot(loop818.loc[station,"no2_no3"], loop818.loc[station,"depth"],'.m')
        plt.plot(loop818.loc[station,"si_oh4"], loop818.loc[station,"depth"],'.c')
        plt.ylim (0,50)
        plt.legend (["Nitrite/Nitrate", "Silicate"], shadow=True, fontsize = '10', loc = 'best')
        plt.tick_params(labelsize=17)
        plt.gca ().invert_yaxis ()
        plt.grid ()
        plt.savefig("{}.png".format(station))
    except KeyError:
        print ("key does not exist "+str(station))
# Out:
# key does not exist 140
# key does not exist 141
# key does not exist 144
# key does not exist 146
# key does not exist 147
# key does not exist 152
# key does not exist 154
# key does not exist 155
# key does not exist 156

# %%
#loop818.loc[station,"depth"]

# %%
#plt.set_title (loop818.loc[station,"Date" "August 2018"] )

# %%
stations1118["date"]
# Out:
# 0      2018-11-02 03:00:00
# 1      2018-11-02 03:00:00
# 2      2018-11-02 03:00:00
# 3      2018-11-02 03:00:00
# 4      2018-11-02 03:00:00
#                ...
# 1446   2018-11-12 23:07:00
# 1447   2018-11-12 23:07:00
# 1448   2018-11-12 23:07:00
# 1449   2018-11-12 23:07:00
# 1450   2018-11-12 23:07:00
# Name: date, Length: 1451, dtype: datetime64[ns]

# %%
#plt.title (loop818.loc[station,"date"])

# %%
#"{}.png".format(loopObject)

# %%
#date82018 = pd.to_datetime(date82018)
#date112018 = pd.to_datetime(date112018)
#date52019 = pd.to_datetime(date52019)
#date102019 = pd.to_datetime(date102019)

# %%
date1118 = stations1118["date"]

# %%
date1118 = pd.to_datetime (date1118)

# %%
stations1118["date"] = pd.to_datetime (stations1118["date"])

# %%
for station in stations:
    try:
        data = loop1118.loc[station,"temperature"]
        f, axs = plt.subplots(4,1, sharey ='all', figsize=(15,10))
        plt.suptitle("Station: {} from {} to {}".format(station, stations1118["date"].min().date(), stations1118["date"].max().date()))
        #plot 1
        plt.subplot(131)
        plt.plot(loop1118.loc[station,"temperature"], loop1118.loc[station,"depth"], '.r')
        plt.plot(loop1118.loc[station,"salinity"], loop1118.loc[station,"depth"], '.b')
        plt.ylim (0,50)
        plt.legend (["Temperature (°C)", "Salinity (PSU)"], shadow=True, fontsize = '18', loc = 'best')
        plt.tick_params(labelsize=17)
        plt.gca ().invert_yaxis ()
        plt.grid ()
        #plot 2
        plt.subplot(132)
        plt.plot(loop1118.loc[station,"chl_a"], loop1118.loc[station,"depth"], '.g')
        plt.plot(loop1118.loc[station,"tot_chl_a"], loop1118.loc[station,"depth"], '.g')
        plt.ylim (0,50)
        plt.legend (["Chlorophyll (uG/L)", "Total Chlorophyll (uG/L)"], shadow=True, fontsize = '10', loc = 'best')
        plt.tick_params(labelsize=17)
        plt.gca ().invert_yaxis ()
        plt.grid ()
        #plot 3
        plt.subplot(133)
        plt.plot(loop1118.loc[station,"no2_no3"], loop1118.loc[station,"depth"],'.m')
        plt.plot(loop1118.loc[station,"si_oh4"], loop1118.loc[station,"depth"],'.c')
        plt.ylim (0,50)
        plt.legend (["Nitrite/Nitrate", "Silicate"], shadow=True, fontsize = '10', loc = 'best')
        plt.tick_params(labelsize=17)
        plt.gca ().invert_yaxis ()
        plt.grid ()
        plt.savefig("{}.png".format(station))
    except KeyError:
        print ("key does not exist "+str(station))
# Out:
# key does not exist 164
# key does not exist 165
# key does not exist 166
# key does not exist 167
# key does not exist 171
# key does not exist 172
# key does not exist 173
# key does not exist 176
# key does not exist 177
# key does not exist 181
# key does not exist 182
# key does not exist 184
# key does not exist 185
# key does not exist 186
# key does not exist 187
# key does not exist 188
# key does not exist 190
# key does not exist 191

# %%
print ("{} {} to {}".format(station, stations818["date"].min().date(), stations818["date"].max().date()))
# Out:
# 159 2018-08-23 to 2018-08-29

# %%
#plt.savefig("{}.png".format(station))

# %%
plt.subplots()
# Out:
#   File "<ipython-input-39-4d11cd137995>", line 2
#     plt.title "ujfh"
#                    ^
# SyntaxError: invalid syntax

# %%
for station in stations:
    try:
        data = loop818.loc[station,"temperature"]
        f, axs = plt.subplots(4,1, sharey ='all', figsize=(15,10))
        plt.suptitle("Station: {} from {} to {}".format(station, stations818["date"].min().date(), stations818["date"].max().date()))
        #plot 1
        plt.subplot(131)
        plt.plot(loop818.loc[station,"temperature"], loop818.loc[station,"depth"], '.r')
        plt.plot(loop818.loc[station,"salinity"], loop818.loc[station,"depth"], '.b')
        plt.ylim (0,50)
        plt.legend (["Temperature (°C)", "Salinity (PSU)"], shadow=True, fontsize = '18', loc = 'best')
        plt.tick_params(labelsize=17)
        plt.gca ().invert_yaxis ()
        plt.grid ()
        #plot 2
        plt.subplot(132)
        plt.plot(loop818.loc[station,"chl_a"], loop818.loc[station,"depth"], '.g')
        plt.plot(loop818.loc[station,"tot_chl_a"], loop818.loc[station,"depth"], '.g')
        plt.ylim (0,50)
        plt.legend (["Chlorophyll (uG/L)", "Total Chlorophyll (uG/L)"], shadow=True, fontsize = '10', loc = 'best')
        plt.tick_params(labelsize=17)
        plt.gca ().invert_yaxis ()
        plt.grid ()
        #plot 3
        plt.subplot(133)
        plt.plot(loop818.loc[station,"no2_no3"], loop818.loc[station,"depth"],'.m')
        plt.plot(loop818.loc[station,"si_oh4"], loop818.loc[station,"depth"],'.c')
        plt.ylim (0,50)
        plt.legend (["Nitrite/Nitrate", "Silicate"], shadow=True, fontsize = '10', loc = 'best')
        plt.tick_params(labelsize=17)
        plt.gca ().invert_yaxis ()
        plt.grid ()
    except KeyError:
        print ("key does not exist "+str(station))
# Out:
# key does not exist 140
# key does not exist 141
# key does not exist 144
# key does not exist 146
# key does not exist 147
# key does not exist 152
# key does not exist 154
# key does not exist 155
# key does not exist 156
